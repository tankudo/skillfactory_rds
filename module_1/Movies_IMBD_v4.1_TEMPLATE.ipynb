# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue  \
# 1402  tt0382992  135000000   76932943
# 225   tt3210686   22000000   67800064
# 1654  tt0241025   23000000   16123851
# 485   tt1314655   10000000   33583175
# 1110  tt0311113  150000000  212011111
#
#                                        original_title  \
# 1402                                          Stealth
# 225                                        Son of God
# 1654                                      Vanity Fair
# 485                                             Devil
# 1110  Master and Commander: The Far Side of the World
#
#                                                    cast             director  \
# 1402  Josh Lucas|Jessica Biel|Jamie Foxx|Sam Shepard...            Rob Cohen
# 225   Roma Downey|Diogo Morgado|Louise Delamere|Darw...  Christopher Spencer
# 1654  Reese Witherspoon|James Purefoy|Jonathan Rhys ...            Mira Nair
# 485   Chris Messina|Jacob Vargas|Bojana NovakoviÄ‡|L...    John Erick Dowdle
# 1110  Russell Crowe|Paul Bettany|James D'Arcy|Billy ...           Peter Weir
#
#                                                 tagline  \
# 1402                                       Fear The Sky
# 225                          Their Empire. His Kingdom.
# 1654             On September 1st, a heroine will rise.
# 485                      Bad Things Happen For A Reason
# 1110  The Courage to Do the Impossible Lies in the H...
#
#                                                overview  runtime  \
# 1402  Deeply ensconced in a top-secret military prog...      121
# 225   The life story of Jesus is told from his humbl...      138
# 1654  Beautiful, funny, passionate, and calculating,...      141
# 485   A group of people trapped in a elevator realiz...       80
# 1110  After an abrupt and violent encounter with a F...      138
#
#                        genres  \
# 1402                   Action
# 225                     Drama
# 1654            Drama|Romance
# 485   Horror|Mystery|Thriller
# 1110                Adventure
#
#                                    production_companies release_date  \
# 1402  Laura Ziskin Productions|Original Film|Columbi...    7/28/2005
# 225   Hearst Entertainment Productions|LightWorkers ...    2/28/2014
# 1654                      Alliance Films|Focus Features     9/1/2004
# 485   Universal Pictures|Media Rights Capital|Night ...    1/13/2010
# 1110  Universal Pictures|Twentieth Century Fox Film ...   11/14/2003
#
#       vote_average  release_year
# 1402           5.0          2005
# 225            5.8          2014
# 1654           5.5          2004
# 485            5.6          2010
# 1110           6.6          2003

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:
#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...
data['profit'] = data.revenue - data.budget
def countFreq(s):
    ganreList = []
    for x in s:
        for xl in x:
            ganreList.append(xl)
    return Counter(ganreList).most_common(1)

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '723. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data[['original_title', 'imdb_id', 'budget']].sort_values(by=['budget'], ascending=False).head(1)
# Out:
#                                   original_title    imdb_id     budget
# 723  Pirates of the Caribbean: On Stranger Tides  tt1298650  380000000

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения
data[data.budget == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit
# 723           6.3          2011  641683000

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '1157. Gods and Generals (tt0279111)'

# %%
data.sort_values(by=['runtime'], ascending = False).head(1)
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '768. Winnie the Pooh (tt1449283)'

# %%
data.sort_values(by=['runtime']).head(1)
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '110'

# %%
round(data['runtime'].mean())
# Out:
# 110

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107'

# %%
round(data['runtime'].median())
# Out:
# 107

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '239. Avatar (tt0499549)'

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
data.sort_values(by='profit', ascending = False).head(1)
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '1245. The Lone Ranger (tt1210819)'

# %%
data['profit'] = data.revenue - data.budget
data.sort_values(by='profit').head(1)
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478'

# %%
len(data[data.revenue > data.budget])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '599. The Dark Knight (tt0468569)'

# %%
data2008 = data[data.release_year == 2008]
data2008.sort_values(by='revenue', ascending = False).head(1)
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# ВАРИАНТ 2

# %%
data.query('release_year == 2008').query('revenue == revenue.max()')
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# ВАРИАНТ 3

# %%
data[data.revenue == data.revenue[data.release_year==2008].max()]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '1245. The Lone Ranger (tt1210819)'

# %%
data12_14=data[(data.release_year >= 2012) & (data.release_year <= 2014)]
data12_14.sort_values(by='profit').head(1)
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# ВАРИАНТ 2

# %%
data[data.profit == data.profit[(data.release_year >= 2012) & (data.release_year <= 2014)].min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = 'Drama'

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
s = data['genres'].str.split('|')
countFreq(s)
# Out:
# [('Drama', 782)]

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama'

# %%
onlyProfit = data[data.profit >= 0]
s1 = onlyProfit['genres'].str.split('|')
countFreq(s1)
# Out:
# [('Drama', 560)]

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson'

# %%
directors = data[['director', 'revenue']]
directors.groupby(by = 'director')['revenue'].sum().sort_values().tail(1)
# Out:
# director
# Peter Jackson    6490593685
# Name: revenue, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Rob Cohen'

# %%
data['genres'].str.split('|', n=1, expand = True)
action_dir = data[data['genres'] == 'Action']
action_top = action_dir.groupby(['director'])['genres'].sum().sort_values(ascending=False)
action_top.index[0]
# Out:
# 'Rob Cohen'

# %%
action_dir = data[data['genres'].str.contains('Action')]
action_top = action_dir.groupby(['director'])['genres'].sum().sort_values(ascending=False)
action_top.index[0]
# Out:
# director
# Oliver Stone                            War|History|Action|Adventure|Drama
# George Clooney                                    War|Drama|History|Action
# David Ayer               War|Drama|ActionAction|Drama|Thriller|CrimeAct...
# Dan Bradley                            War|Action|Thriller|Science Fiction
# Clint Eastwood           War|ActionAction|Adventure|Drama|WarAction|Adv...
#                                                ...
# Sydney Pollack                                                      Action
# Joseph Kahn                                                         Action
# Paul McGuigan                                                       Action
# Christopher McQuarrie                                               Action
# Kevin Macdonald                                                     Action
# Name: genres, Length: 345, dtype: object

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
data['cast'].str.split('|', n=1, expand = True)
data[data.release_year==2012].sort_values(by='revenue', ascending = False).groupby(['cast']).max()
# Out:
#                                                       imdb_id     budget  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...  tt0837562   85000000
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...  tt1232200   70000000
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...  tt0938330   20000000
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...  tt0948470  215000000
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...  tt1981677   17000000
# ...                                                       ...        ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...  tt1712170   45000000
# Victoria Justice|Jackson Nicoll|Chelsea Handler...  tt1663143   14000000
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...  tt1876451   14000000
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...  tt1409024  225000000
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...  tt1482459   70000000
#
#                                                       revenue  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...  358375603
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...   58058367
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...   52302796
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...  752215857
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...  115350426
# ...                                                       ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...   30353232
# Victoria Justice|Jackson Nicoll|Chelsea Handler...   11417362
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...   24637469
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...  624026776
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...  348840316
#
#                                                                 original_title  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...          Hotel Transylvania
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...               That's My Boy
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...  Silent Hill: Revelation 3D
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...      The Amazing Spider-Man
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...               Pitch Perfect
# ...                                                                        ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...                  Alex Cross
# Victoria Justice|Jackson Nicoll|Chelsea Handler...                    Fun Size
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...                     Sparkle
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...              Men in Black 3
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...                   The Lorax
#
#                                                                    director  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...       Genndy Tartakovsky
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...              Sean Anders
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...       Michael J. Bassett
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...                Marc Webb
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...              Jason Moore
# ...                                                                     ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...                Rob Cohen
# Victoria Justice|Jackson Nicoll|Chelsea Handler...            Josh Schwartz
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...               Salim Akil
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...         Barry Sonnenfeld
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...  Chris Renaud|Kyle Balda
#
#                                                                                               tagline  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...          Where monsters go to get away from it all
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...               The story of a childâ€¦ and his son.
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...  This Halloween prepare for a 3D ride through h...
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...                           The untold story begins.
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...                                 Get pitch slapped.
# ...                                                                                               ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...                        Don't Ever Cross Alex Cross
# Victoria Justice|Jackson Nicoll|Chelsea Handler...           Some people just can't handle Halloween.
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...                              Celebrate the legend.
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...                          They are back... in time.
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...                  Meet The Original Force Of Nature
#
#                                                                                              overview  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...  Dracula, who operates a high-end resort away f...
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...  While in his teens, Donny fathered a son, Todd...
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...  Heather Mason and her father have been on the ...
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...  Peter Parker is an outcast high schooler was a...
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...  College student Beca knows she does not want t...
# ...                                                                                               ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...  After Washington DC detective Alex Cross is to...
# Victoria Justice|Jackson Nicoll|Chelsea Handler...  Wren (Victoria Justice) is invited to a Hallow...
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...  Musical prodigy, Sparkle (Jordin Sparks) strug...
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...  Agents J (Will Smith) and K (Tommy Lee Jones) ...
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...  A 12-year-old boy searches for the one thing t...
#
#                                                     runtime  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...       91
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...      116
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...       94
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...      136
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...      112
# ...                                                     ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...      101
# Victoria Justice|Jackson Nicoll|Chelsea Handler...       87
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...      116
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...      106
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...       86
#
#                                                                              genres  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...  Animation|Comedy|Family|Fantasy
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...                           Comedy
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...          Thriller|Horror|Mystery
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...         Action|Adventure|Fantasy
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...             Comedy|Music|Romance
# ...                                                                             ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...    Action|Thriller|Crime|Mystery
# Victoria Justice|Jackson Nicoll|Chelsea Handler...                           Comedy
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...                      Drama|Music
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...    Action|Comedy|Science Fiction
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...                 Animation|Family
#
#                                                                                  production_companies  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...          Columbia Pictures|Sony Pictures Animation
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...  Columbia Pictures|Happy Madison Productions|Re...
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...                Davis-Films|Konami Corporation Ltd.
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...  Columbia Pictures|Laura Ziskin Productions|Mar...
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...                             Brownstone Productions
# ...                                                                                               ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...                               Summit Entertainment
# Victoria Justice|Jackson Nicoll|Chelsea Handler...  Paramount Pictures|Nickelodeon Movies|Anonymou...
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...  TriStar Pictures|Phoenix Pictures|Stage 6 Film...
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...  Amblin Entertainment|Media Magik Entertainment...
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...      Universal Pictures|Illumination Entertainment
#
#                                                    release_date  vote_average  \
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...    9/20/2012           6.7
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...    6/14/2012           5.6
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...   10/10/2012           5.1
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...    6/27/2012           6.4
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...    9/28/2012           7.2
# ...                                                         ...           ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...   10/18/2012           5.2
# Victoria Justice|Jackson Nicoll|Chelsea Handler...   10/25/2012           5.4
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...    8/17/2012           5.9
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...    5/23/2012           6.1
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...     3/1/2012           6.3
#
#                                                     release_year     profit
# cast
# Adam Sandler|Steve Buscemi|David Spade|Kevin Ja...          2012  273375603
# Adam Sandler|Susan Sarandon|Eva Amurri Martino|...          2012  -11941633
# Adelaide Clemens|Kit Harington|Sean Bean|Carrie...          2012   32302796
# Andrew Garfield|Emma Stone|Rhys Ifans|Denis Lea...          2012  537215857
# Anna Kendrick|Skylar Astin|Brittany Snow|Anna C...          2012   98350426
# ...                                                          ...        ...
# Tyler Perry|Rachel Nichols|Jean Reno|Matthew Fo...          2012  -14646768
# Victoria Justice|Jackson Nicoll|Chelsea Handler...          2012   -2582638
# Whitney Houston|Cee Lo Green|Derek Luke|Mike Ep...          2012   10637469
# Will Smith|Tommy Lee Jones|Josh Brolin|Michael ...          2012  399026776
# Zac Efron|Danny DeVito|Taylor Swift|Ed Helms|Ro...          2012  278840316
#
# [111 rows x 14 columns]

# %%
dataC = data['cast'].str.split('|',n = 15).tolist()
dataC
# Out:
# [['Chris Pratt',
#   'Bryce Dallas Howard',
#   'Irrfan Khan',
#   "Vincent D'Onofrio",
#   'Nick Robinson'],
#  ['Tom Hardy',
#   'Charlize Theron',
#   'Hugh Keays-Byrne',
#   'Nicholas Hoult',
#   'Josh Helman'],
#  ['Shailene Woodley',
#   'Theo James',
#   'Kate Winslet',
#   'Ansel Elgort',
#   'Miles Teller'],
#  ['Harrison Ford',
#   'Mark Hamill',
#   'Carrie Fisher',
#   'Adam Driver',
#   'Daisy Ridley'],
#  ['Vin Diesel',
#   'Paul Walker',
#   'Jason Statham',
#   'Michelle Rodriguez',
#   'Dwayne Johnson'],
#  ['Leonardo DiCaprio',
#   'Tom Hardy',
#   'Will Poulter',
#   'Domhnall Gleeson',
#   'Paul Anderson'],
#  ['Arnold Schwarzenegger',
#   'Jason Clarke',
#   'Emilia Clarke',
#   'Jai Courtney',
#   'J.K. Simmons'],
#  ['Matt Damon',
#   'Jessica Chastain',
#   'Kristen Wiig',
#   'Jeff Daniels',
#   'Michael PeÃ±a'],
#  ['Sandra Bullock',
#   'Jon Hamm',
#   'Michael Keaton',
#   'Allison Janney',
#   'Steve Coogan'],
#  ['Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader', 'Lewis Black'],
#  ['Daniel Craig',
#   'Christoph Waltz',
#   'LÃ©a Seydoux',
#   'Ralph Fiennes',
#   'Monica Bellucci'],
#  ['Mila Kunis',
#   'Channing Tatum',
#   'Sean Bean',
#   'Eddie Redmayne',
#   'Douglas Booth'],
#  ['Domhnall Gleeson',
#   'Alicia Vikander',
#   'Oscar Isaac',
#   'Sonoya Mizuno',
#   'Corey Johnson'],
#  ['Adam Sandler',
#   'Michelle Monaghan',
#   'Peter Dinklage',
#   'Josh Gad',
#   'Kevin James'],
#  ['Robert Downey Jr.',
#   'Chris Hemsworth',
#   'Mark Ruffalo',
#   'Chris Evans',
#   'Scarlett Johansson'],
#  ['Samuel L. Jackson',
#   'Kurt Russell',
#   'Jennifer Jason Leigh',
#   'Walton Goggins',
#   'DemiÃ¡n Bichir'],
#  ['Liam Neeson',
#   'Forest Whitaker',
#   'Maggie Grace',
#   'Famke Janssen',
#   'Dougray Scott'],
#  ['Paul Rudd',
#   'Michael Douglas',
#   'Evangeline Lilly',
#   'Corey Stoll',
#   'Bobby Cannavale'],
#  ['Lily James',
#   'Cate Blanchett',
#   'Richard Madden',
#   'Helena Bonham Carter',
#   'Holliday Grainger'],
#  ['Jennifer Lawrence',
#   'Josh Hutcherson',
#   'Liam Hemsworth',
#   'Woody Harrelson',
#   'Elizabeth Banks'],
#  ['Britt Robertson',
#   'George Clooney',
#   'Raffey Cassidy',
#   'Thomas Robinson',
#   'Hugh Laurie'],
#  ['Jake Gyllenhaal',
#   'Rachel McAdams',
#   'Forest Whitaker',
#   'Oona Laurence',
#   '50 Cent'],
#  ['Dwayne Johnson',
#   'Alexandra Daddario',
#   'Carla Gugino',
#   'Ioan Gruffudd',
#   'Archie Panjabi'],
#  ['Dakota Johnson',
#   'Jamie Dornan',
#   'Jennifer Ehle',
#   'Eloise Mumford',
#   'Victor Rasuk'],
#  ['Christian Bale',
#   'Steve Carell',
#   'Ryan Gosling',
#   'Brad Pitt',
#   'Melissa Leo'],
#  ['Tom Cruise',
#   'Jeremy Renner',
#   'Simon Pegg',
#   'Rebecca Ferguson',
#   'Ving Rhames'],
#  ['Mark Wahlberg',
#   'Seth MacFarlane',
#   'Amanda Seyfried',
#   'Jessica Barth',
#   'Giovanni Ribisi'],
#  ['Taron Egerton',
#   'Colin Firth',
#   'Samuel L. Jackson',
#   'Michael Caine',
#   'Mark Strong'],
#  ['Mark Ruffalo',
#   'Michael Keaton',
#   'Rachel McAdams',
#   'Liev Schreiber',
#   'John Slattery'],
#  ["Dylan O'Brien",
#   'Kaya Scodelario',
#   'Thomas Brodie-Sangster',
#   'Giancarlo Esposito',
#   'Aidan Gillen'],
#  ['Sharlto Copley',
#   'Dev Patel',
#   'Ninja',
#   'Yolandi Visser',
#   'Jose Pablo Cantillo'],
#  ['Anna Kendrick',
#   'Rebel Wilson',
#   'Hailee Steinfeld',
#   'Brittany Snow',
#   'Skylar Astin'],
#  ['Tom Hanks', 'Mark Rylance', 'Amy Ryan', 'Alan Alda', 'Sebastian Koch'],
#  ['Jack Black', 'Dylan Minnette', 'Odeya Rush', 'Amy Ryan', 'Jillian Bell'],
#  ['Brie Larson',
#   'Jacob Tremblay',
#   'Joan Allen',
#   'Sean Bridgers',
#   'William H. Macy'],
#  ['Raymond Ochoa',
#   'Jack Bright',
#   'Jeffrey Wright',
#   'Frances McDormand',
#   'Maleah Nipay-Padilla'],
#  ['Liam Neeson',
#   'Ed Harris',
#   'Joel Kinnaman',
#   'Boyd Holbrook',
#   'Bruce McGill'],
#  ['Saoirse Ronan',
#   'Domhnall Gleeson',
#   'Emory Cohen',
#   'Emily Bett Rickards',
#   "Eileen O'Higgins"],
#  ["O'Shea Jackson Jr.",
#   'Corey Hawkins',
#   'Jason Mitchell',
#   'Neil Brown Jr.',
#   'Aldis Hodge'],
#  ['Vin Diesel',
#   'Rose Leslie',
#   'Michael Caine',
#   'Elijah Wood',
#   'Ã“lafur Darri Ã“lafsson'],
#  ['Henry Cavill',
#   'Armie Hammer',
#   'Alicia Vikander',
#   'Elizabeth Debicki',
#   'Luca Calvani'],
#  ['Blake Lively',
#   'Michiel Huisman',
#   'Harrison Ford',
#   'Ellen Burstyn',
#   'Kathy Baker'],
#  ['Sharlto Copley',
#   'Haley Bennett',
#   'Danila Kozlovskiy',
#   'Tim Roth',
#   'Andrei Dementiev'],
#  ['Jim Parsons', 'Rihanna', 'Steve Martin', 'Jennifer Lopez', 'Matt Jones'],
#  ['Nat Wolff',
#   'Cara Delevingne',
#   'Halston Sage',
#   'Justice Smith',
#   'Austin Abrams'],
#  ['Cate Blanchett',
#   'Rooney Mara',
#   'Kyle Chandler',
#   'Sarah Paulson',
#   'Jake Lacy'],
#  ['Robert De Niro',
#   'Anne Hathaway',
#   'Rene Russo',
#   'Anders Holm',
#   'JoJo Kushner'],
#  ['Jason Clarke',
#   'Jake Gyllenhaal',
#   'Josh Brolin',
#   'John Hawkes',
#   'Sam Worthington'],
#  ['Edgar RamÃ\xadrez',
#   'Luke Bracey',
#   'Teresa Palmer',
#   'Delroy Lindo',
#   'Ray Winstone'],
#  ['Bradley Cooper',
#   'Sienna Miller',
#   'Lily James',
#   'Alicia Vikander',
#   'Uma Thurman'],
#  ['Ryan Reynolds',
#   'Ben Kingsley',
#   'Natalie Martinez',
#   'Matthew Goode',
#   'Michelle Dockery'],
#  ['Johnny Depp',
#   'Gwyneth Paltrow',
#   'Ewan McGregor',
#   'Paul Bettany',
#   'Olivia Munn'],
#  ['Eddie Redmayne',
#   'Alicia Vikander',
#   'Matthias Schoenaerts',
#   'Amber Heard',
#   'Ben Whishaw'],
#  ['Chris Hemsworth',
#   'Leehom Wang',
#   'Tang Wei',
#   'Viola Davis',
#   'Holt McCallany'],
#  ['Emily Blunt',
#   'Benicio del Toro',
#   'Josh Brolin',
#   'Victor Garber',
#   'Jon Bernthal'],
#  ['Miles Teller',
#   'Kate Mara',
#   'Michael B. Jordan',
#   'Jamie Bell',
#   'Toby Kebbell'],
#  ['Melissa McCarthy',
#   'Jason Statham',
#   'Rose Byrne',
#   'Miranda Hart',
#   'Bobby Cannavale'],
#  ['Will Smith',
#   'Margot Robbie',
#   'Rodrigo Santoro',
#   'Robert Taylor',
#   'Gerald McRaney'],
#  ['Rupert Friend',
#   'Zachary Quinto',
#   'Hannah Ware',
#   'Emilio Rivera',
#   'Rolf Kanies'],
#  ['Chris Hemsworth',
#   'Benjamin Walker',
#   'Cillian Murphy',
#   'Brendan Gleeson',
#   'Ben Whishaw'],
#  ['Michael B. Jordan',
#   'Sylvester Stallone',
#   'Graham McTavish',
#   'Tessa Thompson',
#   'Phylicia RashÄd'],
#  ['Amy Schumer', 'Bill Hader', 'Brie Larson', 'Colin Quinn', 'Vanessa Bayer'],
#  ['Helen Mirren', 'Aaron Paul', 'Alan Rickman', 'Iain Glen', 'Barkhad Abdi'],
#  ['Tom Hardy',
#   'Emily Browning',
#   'Christopher Eccleston',
#   'David Thewlis',
#   'Taron Egerton'],
#  ['Levi Miller',
#   'Garrett Hedlund',
#   'Hugh Jackman',
#   'Rooney Mara',
#   'Amanda Seyfried'],
#  ['Noah Schnapp',
#   'Bill Melendez',
#   'Venus Schultheis',
#   'Hadley Belle Miller',
#   'Madisyn Shipman'],
#  ['Will Smith',
#   'Bitsie Tulloch',
#   'Gugu Mbatha-Raw',
#   'Alec Baldwin',
#   'Matthew Willig'],
#  ['Joseph Gordon-Levitt',
#   'Seth Rogen',
#   'Anthony Mackie',
#   'Lizzy Caplan',
#   'Jillian Bell'],
#  ['Scott Eastwood',
#   'Britt Robertson',
#   'Lolita Davidovich',
#   'Melissa Benoist',
#   'Jack Huston'],
#  ['Adam Sandler',
#   'Andy Samberg',
#   'Selena Gomez',
#   'Kevin James',
#   'Steve Buscemi'],
#  ['Steve Martin',
#   'Diane Keaton',
#   'John Goodman',
#   'Alan Arkin',
#   'Olivia Wilde'],
#  ['Joseph Gordon-Levitt',
#   'Ben Kingsley',
#   'Charlotte Le Bon',
#   'Ben Schwartz',
#   'James Badge Dale'],
#  ['Ed Helms',
#   'Christina Applegate',
#   'Skyler Gisondo',
#   'Steele Stebbins',
#   'Chris Hemsworth'],
#  ['Sam Rockwell',
#   'Rosemarie DeWitt',
#   'Saxon Sharbino',
#   'Kyle Catlett',
#   'Kennedi Clements'],
#  ['Tom Hardy',
#   'Gary Oldman',
#   'Noomi Rapace',
#   'Joel Kinnaman',
#   'Paddy Considine'],
#  ['Jason Bateman',
#   'Rebecca Hall',
#   'Joel Edgerton',
#   'David Denman',
#   'Beau Knapp'],
#  ['Will Ferrell',
#   'Mark Wahlberg',
#   'Linda Cardellini',
#   'Thomas Haden Church',
#   'Hannibal Buress'],
#  ['Jeff Bridges',
#   'Rachel McAdams',
#   'Paul Rudd',
#   'Marion Cotillard',
#   'James Franco'],
#  ['Kate Winslet',
#   'Liam Hemsworth',
#   'Caroline Goodall',
#   'Judy Davis',
#   'Hayley Magnus'],
#  ['Mae Whitman',
#   'Robbie Amell',
#   'Bella Thorne',
#   'Bianca A. Santos',
#   'Skyler Samuels'],
#  ['Shannyn Sossamon',
#   'James Ransone',
#   'Tate Ellington',
#   'Nicholas King',
#   'Lucas Jade Zumann'],
#  ['Kevin James',
#   'Raini Rodriguez',
#   'Eduardo VerÃ¡stegui',
#   'Daniella Alonso',
#   'Neal McDonough'],
#  ['Jeremy Piven',
#   'Adrian Grenier',
#   'Jerry Ferrara',
#   'Kevin Connolly',
#   'Kevin Dillon'],
#  ['Kevin Hart', 'Josh Gad', 'Kaley Cuoco', 'Affion Crockett', 'Jorge Garcia'],
#  ['Olivia DeJonge',
#   'Ed Oxenbould',
#   'Kathryn Hahn',
#   'Benjamin Kanes',
#   'Deanna Dunagan'],
#  ['Johnny Depp',
#   'Joel Edgerton',
#   'Benedict Cumberbatch',
#   'Dakota Johnson',
#   'Kevin Bacon'],
#  ['Adam Scott',
#   'Toni Collette',
#   'Allison Tolman',
#   'David Koechner',
#   'Emjay Anthony'],
#  ['Owen Wilson',
#   'Lake Bell',
#   'Pierce Brosnan',
#   'Sterling Jerins',
#   'Spencer Garrett'],
#  ['Helen Mirren',
#   'Ryan Reynolds',
#   'Tatiana Maslany',
#   'Katie Holmes',
#   'Max Irons'],
#  ['Tina Fey',
#   'Amy Poehler',
#   'John Leguizamo',
#   'Ike Barinholtz',
#   'Maya Rudolph'],
#  ['Jonny Weston',
#   'Virginia Gardner',
#   "Sofia Black-D'Elia",
#   'Sam Lerner',
#   'Allen Evangelista'],
#  ['Ed Skrein',
#   'Ray Stevenson',
#   'Loan Chabanol',
#   'Gabriella Wright',
#   'Tatjana PajkoviÄ‡'],
#  ['Mia Wasikowska',
#   'Jessica Chastain',
#   'Tom Hiddleston',
#   'Charlie Hunnam',
#   'Jim Beaver'],
#  ['Channing Tatum',
#   'Matt Bomer',
#   'Joe Manganiello',
#   'Kevin Nash',
#   'Adam RodrÃ\xadguez'],
#  ['Chris J. Murray',
#   'Brit Shaw',
#   'Ivy George',
#   'Lauren Frandsen',
#   'Tyler Craig'],
#  ['Bryan Cranston',
#   'Diane Lane',
#   'Helen Mirren',
#   'Elle Fanning',
#   'Louis C.K.'],
#  ['Chiwetel Ejiofor',
#   'Nicole Kidman',
#   'Julia Roberts',
#   'Dean Norris',
#   'Lyndon Smith'],
#  ['Tom Kenny',
#   'Bill Fagerbakke',
#   'Rodger Bumpass',
#   'Clancy Brown',
#   'Carolyn Lawrence'],
#  ['Thomas Haden Church',
#   'Josh Wiggins',
#   'Lauren Graham',
#   'Robbie Amell',
#   'Mia Xitlali'],
#  ['Sean Penn',
#   'Jasmine Trinca',
#   'Javier Bardem',
#   'Ray Winstone',
#   'Mark Rylance'],
#  ['Reese Witherspoon',
#   'SofÃ\xada Vergara',
#   'Michael Mosley',
#   'John Carroll Lynch',
#   'Richard T. Jones'],
#  ['Dermot Mulroney',
#   'Stefanie Scott',
#   'Lin Shaye',
#   'Leigh Whannell',
#   'Angus Sampson'],
#  ['Maggie Smith',
#   'Alex Jennings',
#   'Frances de la Tour',
#   'Gwen Taylor',
#   'Dominic Cooper'],
#  ['James McAvoy',
#   'Daniel Radcliffe',
#   'Jessica Brown Findlay',
#   'Andrew Scott',
#   'Charles Dance'],
#  ['Meryl Streep',
#   'Kevin Kline',
#   'Mamie Gummer',
#   'Sebastian Stan',
#   'Audra McDonald'],
#  ['Michael Ealy',
#   'Sanaa Lathan',
#   'Morris Chestnut',
#   'Kathryn Morris',
#   'Rutina Wesley'],
#  ['Ben Stiller',
#   'Naomi Watts',
#   'Adam Driver',
#   'Amanda Seyfried',
#   'Charles Grodin'],
#  ['Will Ferrell', 'Kevin Hart', 'Alison Brie', 'Craig T. Nelson', 'T.I.'],
#  ['Carey Mulligan',
#   'Helena Bonham Carter',
#   'Meryl Streep',
#   'Ben Whishaw',
#   'Brendan Gleeson'],
#  ['Zac Efron',
#   'Emily Ratajkowski',
#   'Wes Bentley',
#   'Nick Rotteveel',
#   'Alessandro Lindblad'],
#  ['Jakob Salvati',
#   'Emily Watson',
#   'Cary-Hiroyuki Tagawa',
#   'Michael Rapaport',
#   'David Henrie'],
#  ['Bradley Cooper',
#   'Emma Stone',
#   'Rachel McAdams',
#   'John Krasinski',
#   'Bill Murray'],
#  ['Sandra Bullock',
#   'Anthony Mackie',
#   'Billy Bob Thornton',
#   'Zoe Kazan',
#   'Scoot McNairy'],
#  ['Bill Murray',
#   'Zooey Deschanel',
#   'Bruce Willis',
#   'Kate Hudson',
#   'Taylor Kinney'],
#  ['Robert Redford',
#   'Nick Nolte',
#   'Emma Thompson',
#   'Nick Offerman',
#   'Kristen Schaal'],
#  ['Vince Vaughn',
#   'Dave Franco',
#   'James Marsden',
#   'June Diane Raphael',
#   'Sienna Miller'],
#  ['Kevin Costner',
#   'Jennifer Ehle',
#   'Gillian Jacobs',
#   'Octavia Spencer',
#   'Bill Burr'],
#  ['Aubrey Peeples',
#   'Stefanie Scott',
#   'Aurora Perrineau',
#   'Hayley Kiyoko',
#   'Barnaby Carpenter'],
#  ['Matthew McConaughey',
#   'Jessica Chastain',
#   'Anne Hathaway',
#   'Michael Caine',
#   'Casey Affleck'],
#  ['Chris Pratt',
#   'Zoe Saldana',
#   'Dave Bautista',
#   'Vin Diesel',
#   'Bradley Cooper'],
#  ['Chris Evans',
#   'Scarlett Johansson',
#   'Sebastian Stan',
#   'Samuel L. Jackson',
#   'Robert Redford'],
#  ['Keanu Reeves',
#   'Michael Nyqvist',
#   'Alfie Allen',
#   'Willem Dafoe',
#   'Dean Winters'],
#  ['Jennifer Lawrence',
#   'Josh Hutcherson',
#   'Liam Hemsworth',
#   'Woody Harrelson',
#   'Donald Sutherland'],
#  ['Martin Freeman',
#   'Ian McKellen',
#   'Richard Armitage',
#   'Ken Stott',
#   'Graham McTavish'],
#  ['Scott Adsit', 'Ryan Potter', 'Daniel Henney', 'T.J. Miller', 'Jamie Chung'],
#  ['Benedict Cumberbatch',
#   'Keira Knightley',
#   'Matthew Goode',
#   'Rory Kinnear',
#   'Allen Leech'],
#  ["Dylan O'Brien",
#   'Ki Hong Lee',
#   'Kaya Scodelario',
#   'Aml Ameen',
#   'Blake Cooper'],
#  ['Michael Keaton',
#   'Zach Galifianakis',
#   'Edward Norton',
#   'Emma Stone',
#   'Naomi Watts'],
#  ['Ben Affleck',
#   'Rosamund Pike',
#   'Carrie Coon',
#   'Neil Patrick Harris',
#   'Tyler Perry'],
#  ['Brad Pitt',
#   'Shia LaBeouf',
#   'Logan Lerman',
#   'Michael PeÃ±a',
#   'Jon Bernthal'],
#  ['Ben Stiller',
#   'Rami Malek',
#   'Rebel Wilson',
#   'Robin Williams',
#   'Owen Wilson'],
#  ['Shailene Woodley',
#   'Theo James',
#   'Kate Winslet',
#   'Miles Teller',
#   'Ray Stevenson'],
#  ['Hugh Jackman',
#   'James McAvoy',
#   'Patrick Stewart',
#   'Michael Fassbender',
#   'Ian McKellen'],
#  ['Scarlett Johansson',
#   'Morgan Freeman',
#   'Choi Min-sik',
#   'Amr Waked',
#   'Julian Rhind-Tutt'],
#  ['Megan Fox',
#   'Will Arnett',
#   'William Fichtner',
#   'Alan Ritchson',
#   'Noel Fisher'],
#  ['Cameron Diaz', 'Jason Segel', 'Rob Corddry', 'Ellie Kemper', 'Rob Lowe'],
#  ['Jake Gyllenhaal', 'Rene Russo', 'Riz Ahmed', 'Bill Paxton', 'Kevin Rahm'],
#  ['Mark Wahlberg',
#   'Stanley Tucci',
#   'Nicola Peltz',
#   'Jack Reynor',
#   'Li Bingbing'],
#  ['Ralph Fiennes',
#   'Tony Revolori',
#   'F. Murray Abraham',
#   'Mathieu Amalric',
#   'Adrien Brody'],
#  ['Andy Serkis', 'Jason Clarke', 'Toby Kebbell', 'Keri Russell', 'Judy Greer'],
#  ['Denzel Washington',
#   'Marton Csokas',
#   'ChloÃ« Grace Moretz',
#   'David Harbour',
#   'Haley Bennett'],
#  ['Jason Bateman',
#   'Jason Sudeikis',
#   'Charlie Day',
#   'Jennifer Aniston',
#   'Kevin Spacey'],
#  ['Andrew Garfield', 'Emma Stone', 'Jamie Foxx', 'Dane DeHaan', 'Colm Feore'],
#  ['Tom Cruise',
#   'Emily Blunt',
#   'Brendan Gleeson',
#   'Bill Paxton',
#   'Jonas Armstrong'],
#  ['James Franco', 'Seth Rogen', 'Lizzy Caplan', 'Randall Park', 'Diana Bang'],
#  ['Bradley Cooper', 'Sienna Miller', 'Kyle Gallner', 'Cole Konis', 'Ben Reed'],
#  ['Christian Bale',
#   'Joel Edgerton',
#   'John Turturro',
#   'Aaron Paul',
#   'Ben Mendelsohn'],
#  ['Aaron Taylor-Johnson',
#   'Ken Watanabe',
#   'Elizabeth Olsen',
#   'Bryan Cranston',
#   'Juliette Binoche'],
#  ['Angelina Jolie',
#   'Elle Fanning',
#   'Juno Temple',
#   'Sharlto Copley',
#   'Isobelle Molloy'],
#  ['Pierce Brosnan',
#   'Luke Bracey',
#   'Olga Kurylenko',
#   'Bill Smitrovich',
#   'Amila Terzimehic'],
#  ['Olivia Cooke',
#   'Ana Coto',
#   'Daren Kagasoff',
#   'Bianca A. Santos',
#   'Douglas Smith'],
#  ['Jay Baruchel',
#   'Gerard Butler',
#   'Kristen Wiig',
#   'Jonah Hill',
#   'Cate Blanchett'],
#  ['Sylvester Stallone',
#   'Jason Statham',
#   'Harrison Ford',
#   'Arnold Schwarzenegger',
#   'Mel Gibson'],
#  ['Will Arnett',
#   'Elizabeth Banks',
#   'Craig Berry',
#   'Alison Brie',
#   'David Burrows'],
#  ['Jeff Bridges',
#   'Julianne Moore',
#   'Ben Barnes',
#   'Alicia Vikander',
#   'Kit Harington'],
#  ['Eddie Redmayne',
#   'Felicity Jones',
#   'Harry Lloyd',
#   'David Thewlis',
#   'Emily Watson'],
#  ['Jake Johnson',
#   'Damon Wayans Jr.',
#   'Nina Dobrev',
#   'Rob Riggle',
#   "James D'Arcy"],
#  ['Luke Evans',
#   'Sarah Gadon',
#   'Dominic Cooper',
#   'Art Parkinson',
#   'Charles Dance'],
#  ['Tom McGrath',
#   'Chris Miller',
#   'Christopher Knights',
#   'Conrad Vernon',
#   'John Malkovich'],
#  ['Meryl Streep',
#   'Emily Blunt',
#   'James Corden',
#   'Anna Kendrick',
#   'Chris Pine'],
#  ['Sullivan Stapleton',
#   'Eva Green',
#   'Lena Headey',
#   'Callan Mulvey',
#   'David Wenham'],
#  ['Jeff Bridges',
#   'Meryl Streep',
#   'Brenton Thwaites',
#   'Odeya Rush',
#   'Alexander SkarsgÃ¥rd'],
#  ['Jonah Hill', 'Channing Tatum', 'Dave Franco', 'Ice Cube', 'Nick Offerman'],
#  ['Liam Neeson',
#   'Dan Stevens',
#   'David Harbour',
#   'Boyd Holbrook',
#   'Adam David Thompson'],
#  ['Nicole Kidman',
#   'Peter Capaldi',
#   'Ben Whishaw',
#   'Michael Gambon',
#   'Imelda Staunton'],
#  ['Jennifer Aniston',
#   'Anna Kendrick',
#   'William H. Macy',
#   'Adriana Barraza',
#   'Felicity Huffman'],
#  ['Jon Favreau',
#   'John Leguizamo',
#   'Bobby Cannavale',
#   'Emjay Anthony',
#   'Scarlett Johansson'],
#  ['Frank Grillo',
#   'Carmen Ejogo',
#   'Zach Gilford',
#   'Kiele Sanchez',
#   'ZoÃ« Borde'],
#  ['Nicolas Cage',
#   'Chad Michael Murray',
#   'Lea Thompson',
#   'Nicky Whelan',
#   'Martin Klebba'],
#  ['Oscar Isaac',
#   'Jessica Chastain',
#   'Albert Brooks',
#   'Elyes Gabel',
#   'David Oyelowo'],
#  ['Dwayne Johnson',
#   'Ian McShane',
#   'John Hurt',
#   'Rufus Sewell',
#   'Aksel Hennie'],
#  ['Russell Crowe',
#   'Jennifer Connelly',
#   'Emma Watson',
#   'Logan Lerman',
#   'Anthony Hopkins'],
#  ['Robert Downey Jr.',
#   'Robert Duvall',
#   'Vera Farmiga',
#   "Vincent D'Onofrio",
#   'Jeremy Strong'],
#  ['Drew Barrymore',
#   'Adam Sandler',
#   'Wendi McLendon-Covey',
#   'Bella Thorne',
#   'Terry Crews'],
#  ['Seth Rogen', 'Zac Efron', 'Rose Byrne', 'Dave Franco', 'Ike Barinholtz'],
#  ['ChloÃ« Grace Moretz',
#   'Jamie Blackley',
#   'Liana Liberato',
#   'Mireille Enos',
#   'Stacy Keach'],
#  ['Ryan Guzman',
#   'Briana Evigan',
#   'Stephen Boss',
#   'Misha Gabriel',
#   'Izabella Miko'],
#  ['Shailene Woodley',
#   'Ansel Elgort',
#   'Nat Wolff',
#   'Laura Dern',
#   'Sam Trammell'],
#  ['Ice Cube', 'Kevin Hart', 'John Leguizamo', 'Bruce McGill', 'Tika Sumpter'],
#  ['Joaquin Phoenix',
#   'Josh Brolin',
#   'Owen Wilson',
#   'Katherine Waterston',
#   'Reese Witherspoon'],
#  ['Chris Pine',
#   'Keira Knightley',
#   'Kevin Costner',
#   'Nonso Anozie',
#   'Gemma Chan'],
#  ['Liam Neeson',
#   'Julianne Moore',
#   'Scoot McNairy',
#   'Michelle Dockery',
#   'Nate Parker'],
#  ['Ethan Hawke',
#   'Sarah Snook',
#   'Noah Taylor',
#   'Christopher Kirby',
#   'Madeleine West'],
#  ['Joel Kinnaman',
#   'Gary Oldman',
#   'Michael Keaton',
#   'Abbie Cornish',
#   'Jackie Earle Haley'],
#  ['Johnny Depp',
#   'Paul Bettany',
#   'Rebecca Hall',
#   'Kate Mara',
#   'Morgan Freeman'],
#  ['Cameron Diaz',
#   'Leslie Mann',
#   'Kate Upton',
#   'Don Johnson',
#   'Nikolaj Coster-Waldau'],
#  ['Ty Burrell',
#   'Max Charles',
#   'Ariel Winter',
#   'Allison Janney',
#   'Ellie Kemper'],
#  ['Mickey Rourke',
#   'Jessica Alba',
#   'Josh Brolin',
#   'Joseph Gordon-Levitt',
#   'Rosario Dawson'],
#  ['Jesse Eisenberg',
#   'Anne Hathaway',
#   'Leslie Mann',
#   'Jamie Foxx',
#   'Andy GarcÃ\xada'],
#  ['Jim Carrey',
#   'Jeff Daniels',
#   'Rachel Melvin',
#   'Kathleen Turner',
#   'Brady Bluhm'],
#  ['Matt Damon',
#   'Cate Blanchett',
#   'George Clooney',
#   'Bill Murray',
#   'John Goodman'],
#  ["Jack O'Connell",
#   'Domhnall Gleeson',
#   'Garrett Hedlund',
#   'Takamasa Ishihara',
#   'Finn Wittrock'],
#  ['David Oyelowo',
#   'Tom Wilkinson',
#   'Carmen Ejogo',
#   'AndrÃ© Holland',
#   'Omar J. Dorsey'],
#  ['Kit Harington',
#   'Carrie-Anne Moss',
#   'Emily Browning',
#   'Adewale Akinnuoye-Agbaje',
#   'Jessica Lucas'],
#  ['Michelle Monaghan',
#   'James Marsden',
#   'Liana Liberato',
#   'Luke Bracey',
#   'Gerald McRaney'],
#  ['QuvenzhanÃ© Wallis',
#   'Jamie Foxx',
#   'Rose Byrne',
#   'Cameron Diaz',
#   'Bobby Cannavale'],
#  ['Bill Murray',
#   'Melissa McCarthy',
#   'Naomi Watts',
#   "Chris O'Dowd",
#   'Terrence Howard'],
#  ['Aaron Paul',
#   'Dominic Cooper',
#   'Imogen Poots',
#   'Rami Malek',
#   'RamÃ³n RodrÃ\xadguez'],
#  ['Helen Mirren',
#   'Manish Dayal',
#   'Om Puri',
#   'Charlotte Le Bon',
#   'Rohan Chand'],
#  ['Ben Kingsley',
#   'Isaac Hempstead Wright',
#   'Elle Fanning',
#   'Dee Bradley Baker',
#   'Steve Blum'],
#  ['Amy Adams',
#   'Christoph Waltz',
#   'Krysten Ritter',
#   'Danny Huston',
#   'Jason Schwartzman'],
#  ['Bruce Willis',
#   'Jason Patric',
#   'John Cusack',
#   'Jessica Lowndes',
#   'Gia Mantegna'],
#  ['Richard Armitage',
#   'Sarah Wayne Callies',
#   'Matt Walsh',
#   'Nathan Kress',
#   'Alycia Debnam-Carey'],
#  ['Dane Cook',
#   'Ed Harris',
#   'Julie Bowen',
#   'Curtis Armstrong',
#   'John Michael Higgins'],
#  ['Arnold Schwarzenegger',
#   'Sam Worthington',
#   'Mireille Enos',
#   'Joe Manganiello',
#   'Harold Perrineau'],
#  ['Idris Elba',
#   'Taraji P. Henson',
#   'Leslie Bibb',
#   'Kate del Castillo',
#   'Henry Simmons'],
#  ['Perdita Weeks',
#   'Ben Feldman',
#   'Edwin Hodge',
#   'FranÃ§ois Civil',
#   'Marion Lambert'],
#  ['Steve Carell',
#   'Channing Tatum',
#   'Mark Ruffalo',
#   'Sienna Miller',
#   'Vanessa Redgrave'],
#  ['Alex Pettyfer',
#   'Gabriella Wilde',
#   'Robert Patrick',
#   'Rhys Wakefield',
#   'Emma Rigby'],
#  ['Guy Pearce',
#   'Robert Pattinson',
#   'Scoot McNairy',
#   'Nash Edgerton',
#   'Anthony Hayes'],
#  ['Michelle Williams',
#   'Kristin Scott Thomas',
#   'Matthias Schoenaerts',
#   'Sam Riley',
#   'Ruth Wilson'],
#  ['Annabelle Wallis',
#   'Alfre Woodard',
#   'Eric Ladin',
#   'Tony Amendola',
#   'Gabriel Bateman'],
#  ['Aaron Eckhart',
#   'Yvonne Strahovski',
#   'Bill Nighy',
#   'Jai Courtney',
#   'Miranda Otto'],
#  ['Zac Efron',
#   'Miles Teller',
#   'Michael B. Jordan',
#   'Imogen Poots',
#   'Mackenzie Davis'],
#  ['Paul Walker', 'David Belle', 'RZA', 'Robert Maillet', 'Carlo Rota'],
#  ['Melissa McCarthy',
#   'Susan Sarandon',
#   'Kathy Bates',
#   'Allison Janney',
#   'Dan Aykroyd'],
#  ['Colin Farrell',
#   'Jessica Brown Findlay',
#   'Russell Crowe',
#   'William Hurt',
#   'Jennifer Connelly'],
#  ['Dan Stevens',
#   'Maika Monroe',
#   'Sheila Kelley',
#   'Ethan Embry',
#   'Joel David Moore'],
#  ['Russell Crowe',
#   'Olga Kurylenko',
#   'Jai Courtney',
#   'Isabel Lucas',
#   'Damon Herriman'],
#  ['Steve Carell',
#   'Jennifer Garner',
#   'Ed Oxenbould',
#   'Dylan Minnette',
#   'Kerris Dorsey'],
#  ['Jason Bateman', 'Tina Fey', 'Adam Driver', 'Rose Byrne', 'Corey Stoll'],
#  ['Kevin Hart',
#   'Michael Ealy',
#   'Regina Hall',
#   'Joy Bryant',
#   'Christopher McDonald'],
#  ['Jon Hamm', 'Bill Paxton', 'Lake Bell', 'Suraj Sharma', 'Aasif Mandvi'],
#  ['Scarlett Johansson',
#   'KryÅ¡tof HÃ¡dek',
#   'Paul Brannigan',
#   'Michael Moreland',
#   'Scott Dymond'],
#  ['Kristen Bell',
#   'Jason Dohring',
#   'Enrico Colantoni',
#   'Chris Lowell',
#   'Percy Daggs III'],
#  ['Roma Downey',
#   'Diogo Morgado',
#   'Louise Delamere',
#   'Darwin Shaw',
#   'Amber Rose Revah'],
#  ['Jim Caviezel',
#   'Michael Chiklis',
#   'Laura Dern',
#   'Clancy Brown',
#   "Ser'Darius Blain"],
#  ['Ashley Hinshaw',
#   "Denis O'Hare",
#   'James Buckley',
#   'Christa Nicola',
#   'Amir K'],
#  ['Jeremy Renner',
#   'Mary Elizabeth Winstead',
#   'Michael Sheen',
#   'Ray Liotta',
#   'Robert Patrick'],
#  ['Morgan Freeman',
#   'Ashley Judd',
#   'Nathan Gamble',
#   'Cozi Zuehlsdorff',
#   'Harry Connick Jr.'],
#  ['Ricky Gervais',
#   'Ty Burrell',
#   'Tina Fey',
#   'Steve Whitmire',
#   'Eric Jacobson'],
#  ['Greg Kinnear',
#   'Kelly Reilly',
#   'Connor Corum',
#   'Thomas Haden Church',
#   'Jon Ted Wynne'],
#  ['Kellan Lutz',
#   'Liam McIntyre',
#   'Gaia Weiss',
#   'Scott Adkins',
#   'Roxanne McKee'],
#  ['Sarah Drew',
#   'Sean Astin',
#   'Patricia Heaton',
#   'Logan White',
#   'Robert Amaya '],
#  ['Teo Halm',
#   'Astro',
#   'Resse Hartwig',
#   'Ella Wahlestedt',
#   'Jason Gray-Stanford'],
#  ['Mark Wahlberg',
#   'John Goodman',
#   'Brie Larson',
#   'Michael Kenneth Williams',
#   'Jessica Lange'],
#  ['Brendan Gleeson',
#   'Taylor Kitsch',
#   'Gordon Pinsent',
#   'Liane Balaban',
#   'Mark Critch'],
#  ['Kevin Sorbo',
#   'Shane Harper',
#   'David A.R. White',
#   'Dean Cain',
#   'Cassidy Gifford'],
#  ['Allison Miller',
#   'Zach Gilford',
#   'Sam Anderson',
#   'Robert Belushi',
#   'Catherine Kresge'],
#  ['Sam Worthington',
#   'Zoe Saldana',
#   'Sigourney Weaver',
#   'Stephen Lang',
#   'Michelle Rodriguez'],
#  ['Brad Pitt',
#   'MÃ©lanie Laurent',
#   'Christoph Waltz',
#   'Eli Roth',
#   'Michael Fassbender'],
#  ['Bill Nighy',
#   'Michael Sheen',
#   'Rhona Mitra',
#   'Shane Brolly',
#   'Steven Mackintosh'],
#  ['Daniel Radcliffe',
#   'Rupert Grint',
#   'Emma Watson',
#   'Tom Felton',
#   'Julie Walters'],
#  ['Ed Asner',
#   'Christopher Plummer',
#   'Jordan Nagai',
#   'Bob Peterson',
#   'Delroy Lindo'],
#  ['Chris Pine',
#   'Zachary Quinto',
#   'Leonard Nimoy',
#   'Eric Bana',
#   'Bruce Greenwood'],
#  ['Christian Bale',
#   'Sam Worthington',
#   'Anton Yelchin',
#   'Moon Bloodgood',
#   'Bryce Dallas Howard'],
#  ['Sharlto Copley',
#   'Jason Cope',
#   'Nathalie Boltt',
#   'Sylvaine Strike',
#   'Elizabeth Mkandawie'],
#  ['Robert Downey Jr.',
#   'Jude Law',
#   'Rachel McAdams',
#   'Mark Strong',
#   'Eddie Marsan'],
#  ['Joseph Gordon-Levitt',
#   'Zooey Deschanel',
#   'ChloÃ« Grace Moretz',
#   'Geoffrey Arend',
#   'Matthew Gray Gubler'],
#  ['Bradley Cooper',
#   'Ed Helms',
#   'Zach Galifianakis',
#   'Justin Bartha',
#   'Heather Graham'],
#  ['Malin Ã…kerman',
#   'Billy Crudup',
#   'Carla Gugino',
#   'Jeffrey Dean Morgan',
#   'Patrick Wilson'],
#  ['John Cusack',
#   'Amanda Peet',
#   'Chiwetel Ejiofor',
#   'Thandie Newton',
#   'Oliver Platt'],
#  ['Elijah Wood',
#   'John C. Reilly',
#   'Jennifer Connelly',
#   'Christopher Plummer',
#   'Crispin Glover'],
#  ['Tom Hanks',
#   'Ewan McGregor',
#   'Ayelet Zurer',
#   'Stellan SkarsgÃ¥rd',
#   'Pierfrancesco Favino'],
#  ['Anika Noni Rose',
#   'Bruno Campos',
#   'Keith David',
#   'Michael-Leon Wooley',
#   'Jennifer Cody'],
#  ['Sandra Bullock', 'Quinton Aaron', 'Kathy Bates', 'Tim McGraw', 'Jae Head'],
#  ['Jesse Eisenberg',
#   'Woody Harrelson',
#   'Emma Stone',
#   'Abigail Breslin',
#   'Amber Heard'],
#  ['Kristen Stewart',
#   'Robert Pattinson',
#   'Taylor Lautner',
#   'Billy Burke',
#   'Ashley Greene'],
#  ['Jennifer Aniston',
#   'Jennifer Connelly',
#   'Drew Barrymore',
#   'Ginnifer Goodwin',
#   'Ben Affleck'],
#  ['Dennis Quaid',
#   'Channing Tatum',
#   'Marlon Wayans',
#   'Sienna Miller',
#   'Joseph Gordon-Levitt'],
#  ['Sandra Bullock',
#   'Ryan Reynolds',
#   'Mary Steenburgen',
#   'Craig T. Nelson',
#   'Betty White'],
#  ['Katherine Heigl',
#   'Gerard Butler',
#   'Eric Winter',
#   'Bree Turner',
#   'Nick Searcy'],
#  ['Bill Hader', 'Anna Faris', 'James Caan', 'Mr. T', 'Benjamin Bratt'],
#  ['George Clooney',
#   'Meryl Streep',
#   'Jason Schwartzman',
#   'Bill Murray',
#   'Wallace Wolodarsky'],
#  ['Dakota Fanning',
#   'Teri Hatcher',
#   'Jennifer Saunders',
#   'Dawn French',
#   'Keith David'],
#  ['Ben Stiller', 'Amy Adams', 'Owen Wilson', 'Hank Azaria', 'Robin Williams'],
#  ['Zac Efron',
#   'Leslie Mann',
#   'Matthew Perry',
#   'Tyler Steelman',
#   'Allison Miller'],
#  ['Gary Oldman', 'Jim Carrey', 'Steve Valentine', 'Daryl Sabara', 'Sage Ryan'],
#  ['Rachel Weisz',
#   'Mark Wahlberg',
#   'Susan Sarandon',
#   'Saoirse Ronan',
#   'Stanley Tucci'],
#  ['Kevin James',
#   "Keir O'Donnell",
#   'Jayma Mays',
#   'Raini Rodriguez',
#   'Shirley Knight'],
#  ['Richard Gere',
#   'Joan Allen',
#   'Jason Alexander',
#   'Cary-Hiroyuki Tagawa',
#   'Sarah Roemer'],
#  ['Jamie Foxx', 'Gerard Butler', 'Colm Meaney', 'Bruce McGill', 'Leslie Bibb'],
#  ['Cameron Diaz',
#   'James Marsden',
#   'Frank Langella',
#   'Michael Zegen',
#   'James Rebhorn'],
#  ['Jason Statham',
#   'Amy Smart',
#   'Dwight Yoakam',
#   'Efren Ramirez',
#   'Julanne Chidi Hill'],
#  ['Ben Foster', 'Dennis Quaid', 'Cam Gigandet', 'Antje Traue', 'Cung Le'],
#  ['Alison Lohman', 'Justin Long', 'Lorna Raver', 'Dileep Rao', 'David Paymer'],
#  ['Nicolas Cage',
#   'Rose Byrne',
#   'Chandler Canterbury',
#   'Ben Mendelsohn',
#   'Nadia Townsend'],
#  ['Sam Rockwell',
#   'Kevin Spacey',
#   'Dominique McElligott',
#   'Rosie Shaw',
#   'Adrienne Shaw'],
#  ['Sam Rockwell',
#   'PenÃ©lope Cruz',
#   'Tracy Morgan',
#   'Jon Favreau',
#   'Steve Buscemi'],
#  ['Denzel Washington',
#   'John Travolta',
#   'Luis GuzmÃ¡n',
#   'Victor Gojcaj',
#   'John Turturro'],
#  ['Ricky Gervais',
#   'Jennifer Garner',
#   'Jonah Hill',
#   'Louis C.K.',
#   'Jeffrey Tambor'],
#  ['Isla Fisher',
#   'Hugh Dancy',
#   'Krysten Ritter',
#   'Joan Cusack',
#   'John Goodman'],
#  ['Gerard Butler',
#   'Michael C. Hall',
#   'Logan Lerman',
#   'Amber Valletta',
#   'Terry Crews'],
#  ['Jared Leto',
#   'Diane Kruger',
#   'Linh Äan Pháº¡m',
#   'Sarah Polley',
#   'Rhys Ifans'],
#  ['Vince Vaughn',
#   'Malin Ã…kerman',
#   'Jason Bateman',
#   'Kristen Bell',
#   'Jon Favreau'],
#  ['Tobey Maguire',
#   'Jake Gyllenhaal',
#   'Natalie Portman',
#   'Sam Shepard',
#   'Mare Winningham'],
#  ['Viggo Mortensen',
#   'Kodi Smit-McPhee',
#   'Charlize Theron',
#   'Robert Duvall',
#   'Guy Pearce'],
#  ['Seth Rogen',
#   'Reese Witherspoon',
#   'Hugh Laurie',
#   'Paul Rudd',
#   'Kiefer Sutherland'],
#  ['Meryl Streep',
#   'Amy Adams',
#   'Stanley Tucci',
#   'Chris Messina',
#   'Linda Emond'],
#  ['Julianne Moore',
#   'Liam Neeson',
#   'Amanda Seyfried',
#   'Max Thieriot',
#   'R. H. Thomson'],
#  ['Christian Bale',
#   'Johnny Depp',
#   'Giovanni Ribisi',
#   'Billy Crudup',
#   'Marion Cotillard'],
#  ['Megan Fox',
#   'Amanda Seyfried',
#   'Johnny Simmons',
#   'Adam Brody',
#   'J.K. Simmons'],
#  ['Vera Farmiga',
#   'Peter Sarsgaard',
#   'Isabelle Fuhrman',
#   'CCH Pounder',
#   'Jimmy Bennett'],
#  ['Sandra Bullock',
#   'Thomas Haden Church',
#   'Bradley Cooper',
#   'Ken Jeong',
#   'DJ Qualls'],
#  ['Bobby Campo',
#   'Shantel VanSanten',
#   'Nick Zano',
#   'Haley Webb',
#   'Krista Allen'],
#  ['Zachary Levi',
#   'David Cross',
#   'Jason Lee',
#   'Justin Long',
#   'Matthew Gray Gubler'],
#  ['Anne Hathaway',
#   'Kate Hudson',
#   'Bryan Greenberg',
#   'Chris Pratt',
#   'Steve Howey'],
#  ['Gabourey Sidibe',
#   "Mo'Nique",
#   'Paula Patton',
#   'Mariah Carey',
#   'Lenny Kravitz'],
#  ['Russell Crowe',
#   'Ben Affleck',
#   'Rachel McAdams',
#   'Robin Wright',
#   'Jason Bateman'],
#  ['Odette Annable',
#   'Gary Oldman',
#   'Meagan Good',
#   'Cam Gigandet',
#   'Idris Elba'],
#  ['Paul Rudd', 'Rashida Jones', 'Jason Segel', 'Sarah Burns', 'Jaime Pressly'],
#  ['Matt Damon', 'Scott Bakula', 'Joel McHale', 'Melanie Lynskey', 'Ann Dowd'],
#  ['Dwayne Johnson',
#   'AnnaSophia Robb',
#   'Alexander Ludwig',
#   'Carla Gugino',
#   'Chris Marquette'],
#  ['RenÃ©e Zellweger',
#   'Jodelle Ferland',
#   'Ian McShane',
#   "Kerry O'Malley",
#   'Callum Keith Rennie'],
#  ['Tom Sturridge',
#   'Philip Seymour Hoffman',
#   'Rhys Ifans',
#   'Bill Nighy',
#   'Emma Thompson'],
#  ['Ethan Hawke',
#   'Sam Neill',
#   'Willem Dafoe',
#   'Claudia Karvan',
#   'Isabel Lucas'],
#  ['Aaron Eckhart',
#   'Jennifer Aniston',
#   'Judy Greer',
#   'Martin Sheen',
#   'Deirdre Blades'],
#  ['Dakota Fanning',
#   'Camilla Belle',
#   'Chris Evans',
#   'Djimon Hounsou',
#   'Maggie Siff'],
#  ['Richard Gere',
#   'Don Cheadle',
#   'Ethan Hawke',
#   'Wesley Snipes',
#   "Vincent D'Onofrio"],
#  ['Tobin Bell',
#   'Costas Mandylor',
#   'Betsy Russell',
#   'Mark Rolston',
#   'Peter Outerbridge'],
#  ['Emily Blunt',
#   'Jim Broadbent',
#   'Mark Strong',
#   'Paul Bettany',
#   'Miranda Richardson'],
#  ['Michael Stuhlbarg',
#   'Richard Kind',
#   'Fred Melamed',
#   'Sari Lennick',
#   'Aaron Wolff'],
#  ['Milla Jovovich',
#   'Timothy Olyphant',
#   'Steve Zahn',
#   'Chris Hemsworth',
#   'Anthony Ruivivar'],
#  ['Kate Beckinsale',
#   'Gabriel Macht',
#   'Tom Skerritt',
#   'Columbus Short',
#   'Shawn Doyle'],
#  ['Jim Carrey',
#   'Ewan McGregor',
#   'Leslie Mann',
#   'Rodrigo Santoro',
#   'Brennan Brown'],
#  ['John Cena',
#   'Ashley Scott',
#   'Brian J. White',
#   'Aidan Gillen',
#   'Steve Harris'],
#  ['Aamir Khan', 'Kareena Kapoor', 'Madhavan', 'Sharman Joshi', 'Boman Irani'],
#  ['Shia LaBeouf',
#   'Megan Fox',
#   'Josh Duhamel',
#   'Rainn Wilson',
#   'Tyrese Gibson'],
#  ['George Clooney',
#   'Ewan McGregor',
#   'Jeff Bridges',
#   'Kevin Spacey',
#   'Robert Patrick'],
#  ['Rain', 'Naomie Harris', 'Sung Kang', 'Randall Duk Kim', 'Rick Yune'],
#  ['Vanessa Hudgens',
#   'Aly Michalka',
#   'Gaelan Connell',
#   'Lisa Kudrow',
#   'Scott Porter'],
#  ['Meryl Streep',
#   'Alec Baldwin',
#   'Steve Martin',
#   'Lake Bell',
#   'Mary Kay Place'],
#  ['Will Ferrell',
#   'Anna Friel',
#   'Danny McBride',
#   'Jorma Taccone',
#   'Matt Lauer'],
#  ['Morgan Freeman',
#   'Matt Damon',
#   'Tony Kgoroge',
#   'Patrick Mofokeng',
#   'Matt Stern'],
#  ['Dwayne Johnson',
#   'Seann William Scott',
#   'Jessica Biel',
#   'Justin Long',
#   'Gary Oldman'],
#  ['Jack Black', 'Michael Cera', 'Olivia Wilde', 'Oliver Platt', 'David Cross'],
#  ['Jensen Ackles', 'Jaime King', 'Kerr Smith', 'Betsy Rue', 'Edi Gathegi'],
#  ['Robin Williams',
#   'John Travolta',
#   'Seth Green',
#   'Justin Long',
#   'Matt Dillon'],
#  ['Rachel Weisz',
#   'Max Minghella',
#   'Oscar Isaac',
#   'Ashraf Barhom',
#   'Michael Lonsdale'],
#  ['Sean Patrick Flanery',
#   'Norman Reedus',
#   'Billy Connolly',
#   'Clifton Collins, Jr.',
#   'Julie Benz'],
#  ['Nicolas Cage', 'Eva Mendes', 'Val Kilmer', 'Fairuza Balk', 'Shawn Hatosy'],
#  ['Columbus Short',
#   'Laurence Fishburne',
#   'Skeet Ulrich',
#   'Amaury Nolasco',
#   'Matt Dillon'],
#  ['John C. Reilly',
#   'Josh Hutcherson',
#   'Chris Massoglia',
#   'Patrick Fugit',
#   'Salma Hayek'],
#  ['Carey Mulligan',
#   'Olivia Williams',
#   'Peter Sarsgaard',
#   'Alfred Molina',
#   'Cara Seymour'],
#  ['Adam Sandler', 'Seth Rogen', 'Leslie Mann', 'Eric Bana', 'Jonah Hill'],
#  ['George Clooney',
#   'Vera Farmiga',
#   'Anna Kendrick',
#   'Jason Bateman',
#   'Melanie Lynskey'],
#  ['Nicolas Cage',
#   'Kristen Bell',
#   'Bill Nighy',
#   'Donald Sutherland',
#   'Freddie Highmore'],
#  ['Clive Owen',
#   'Naomi Watts',
#   'Armin Mueller-Stahl',
#   'Ulrich Thomsen',
#   "BrÃ\xadan F. O'Byrne"],
#  ['Vin Diesel',
#   'Paul Walker',
#   'Jordana Brewster',
#   'Michelle Rodriguez',
#   'John Ortiz'],
#  ['Michael Moore',
#   'Thora Birch',
#   'William Black',
#   'Elijah Cummings',
#   'Baron Hill'],
#  ['Scout Taylor-Compton',
#   'Sheri Moon Zombie',
#   'Tyler Mane',
#   'Chase Wright Vanek',
#   'Brad Dourif'],
#  ['Miley Cyrus',
#   'Billy Ray Cyrus',
#   'Emily Osment',
#   'Jason Earles',
#   'Taylor Swift'],
#  ['Carter Jenkins',
#   'Austin Butler',
#   'Kevin Nealon',
#   'Robert Hoffman',
#   'Doris Roberts'],
#  ['Milla Jovovich',
#   'Will Patton',
#   'Hakeem Kae-Kazim',
#   'Corey Johnson',
#   'Enzo Cilenti'],
#  ['Michael Douglas',
#   'Jesse Eisenberg',
#   'Susan Sarandon',
#   'Mary-Louise Parker',
#   'Jenna Fischer'],
#  ['Clive Owen',
#   'Julia Roberts',
#   'Paul Giamatti',
#   'Tom Wilkinson',
#   'Lisa Roberts Gillan'],
#  ['Abbie Cornish',
#   'Ben Whishaw',
#   'Paul Schneider',
#   'Kerry Fox',
#   'Edie Martin'],
#  ['Jesse Eisenberg',
#   'Kristen Stewart',
#   'Martin Starr',
#   'Kristen Wiig',
#   'Bill Hader'],
#  ['Jason Bateman',
#   'Mila Kunis',
#   'Kristen Wiig',
#   'Ben Affleck',
#   'J.K. Simmons'],
#  ['Nia Vardalos',
#   'Richard Dreyfuss',
#   'Alexis Georgoulis',
#   'Alistair McGowan',
#   'Harland Williams'],
#  ['Cameron Diaz',
#   'Alec Baldwin',
#   'Abigail Breslin',
#   'Joan Cusack',
#   'Sofia Vassilieva'],
#  ['Robert Downey Jr.',
#   'Jamie Foxx',
#   'Catherine Keener',
#   'Nelsan Ellis',
#   'Michael Bunin'],
#  ['Derek Mears',
#   'Jared Padalecki',
#   'Danielle Panabaker',
#   'Amanda Righetti',
#   'Travis Van Winkle'],
#  ['Michael Caine',
#   'Emily Mortimer',
#   'Iain Glen',
#   'Lee Oakes',
#   'Liam Cunningham'],
#  ['Bruce Willis',
#   'Radha Mitchell',
#   'Rosamund Pike',
#   'James Cromwell',
#   'Ving Rhames'],
#  ['Kristin Kreuk',
#   'Chris Klein',
#   'Neal McDonough',
#   'Michael Clarke Duncan',
#   'Moon Bloodgood'],
#  ['Emma Roberts',
#   'Jake T. Austin',
#   'Don Cheadle',
#   'Johnny Simmons',
#   'Kyla Pratt'],
#  ['BeyoncÃ© Knowles',
#   'Idris Elba',
#   'Ali Larter',
#   "Jerry O'Connell",
#   'Bonnie Perlman'],
#  ['James Purefoy',
#   'Pete Postlethwaite',
#   'Alice Krige',
#   'Mackenzie Crook',
#   'Max von Sydow'],
#  ['Hugh Jackman',
#   'Liev Schreiber',
#   'Danny Huston',
#   'Lynn Collins',
#   'Ryan Reynolds'],
#  ['RenÃ©e Zellweger',
#   'Harry Connick Jr.',
#   'J.K. Simmons',
#   'Siobhan Fallon',
#   "Mike O'Brien"],
#  ['Zac Efron', 'Claire Danes', 'Christian McKay', 'Imogen Poots', 'Zoe Kazan'],
#  ['Jimmy Bennett',
#   'Kat Dennings',
#   'Jolie Vanier',
#   'William H. Macy',
#   'James Spader'],
#  ['Rumer Willis',
#   'Briana Evigan',
#   'Jamie Chung',
#   'Leah Pipes',
#   'Teri Andrzejewski'],
#  ['David Duchovny',
#   'Demi Moore',
#   'Amber Heard',
#   'Benjamin Hollingsworth',
#   'Lauren Hutton'],
#  ['Alexis Bledel',
#   'Zach Gilford',
#   'Rodrigo Santoro',
#   'Jane Lynch',
#   'Carol Burnett'],
#  ['Jeff Bridges',
#   'Maggie Gyllenhaal',
#   'Colin Farrell',
#   'Robert Duvall',
#   'Paul Herman'],
#  ['Hugh Grant',
#   'Sarah Jessica Parker',
#   'Mary Steenburgen',
#   'Sam Elliott',
#   'Natalia Klimas'],
#  ['Johanna Braddy',
#   'Gil McKinney',
#   'Emi Ikehata',
#   'Jadie-Rose Hobson',
#   'Beau Mirchoff'],
#  ['Chi Cao', 'Chengwu Guo', 'Wen Bin Huang', 'Joan Chen', 'Bruce Greenwood'],
#  ['Leonardo DiCaprio',
#   'Joseph Gordon-Levitt',
#   'Ellen Page',
#   'Tom Hardy',
#   'Ken Watanabe'],
#  ['Robert Downey Jr.',
#   'Gwyneth Paltrow',
#   'Don Cheadle',
#   'Scarlett Johansson',
#   'Mickey Rourke'],
#  ['Mia Wasikowska',
#   'Johnny Depp',
#   'Anne Hathaway',
#   'Helena Bonham Carter',
#   'Crispin Glover'],
#  ['Natalie Portman',
#   'Mila Kunis',
#   'Vincent Cassel',
#   'Barbara Hershey',
#   'Winona Ryder'],
#  ['Daniel Radcliffe',
#   'Emma Watson',
#   'Rupert Grint',
#   'Ralph Fiennes',
#   'Helena Bonham Carter'],
#  ['Steve Carell',
#   'Jason Segel',
#   'Russell Brand',
#   'Julie Andrews',
#   'Will Arnett'],
#  ['Sylvester Stallone',
#   'Jason Statham',
#   'Dolph Lundgren',
#   'Eric Roberts',
#   'Randy Couture'],
#  ['Jay Baruchel',
#   'Gerard Butler',
#   'Craig Ferguson',
#   'America Ferrera',
#   'Jonah Hill'],
#  ['Leonardo DiCaprio',
#   'Mark Ruffalo',
#   'Ben Kingsley',
#   'Emily Mortimer',
#   'Michelle Williams'],
#  ['Garrett Hedlund',
#   'Jeff Bridges',
#   'Olivia Wilde',
#   'Bruce Boxleitner',
#   'Yaya DaCosta'],
#  ['Zachary Levi', 'Mandy Moore', 'Donna Murphy', 'Ron Perlman', 'M.C. Gainey'],
#  ['Tom Hanks', 'Tim Allen', 'Ned Beatty', 'Joan Cusack', 'Michael Keaton'],
#  ['Angelina Jolie',
#   'Liev Schreiber',
#   'Corey Stoll',
#   'Chiwetel Ejiofor',
#   'Daniel Olbrychski'],
#  ['James Franco',
#   'Kate Mara',
#   'Amber Tamblyn',
#   'ClÃ©mence PoÃ©sy',
#   'Lizzy Caplan'],
#  ['Emma Stone',
#   'Stanley Tucci',
#   'Amanda Bynes',
#   'Cam Gigandet',
#   'Lisa Kudrow'],
#  ['Skandar Keynes',
#   'Georgie Henley',
#   'Simon Pegg',
#   'Gary Sweet',
#   'Arthur Angel'],
#  ['Aaron Taylor-Johnson',
#   'ChloÃ« Grace Moretz',
#   'Christopher Mintz-Plasse',
#   'Nicolas Cage',
#   'Mark Strong'],
#  ['Johnny Depp',
#   'Angelina Jolie',
#   'Paul Bettany',
#   'Timothy Dalton',
#   'Steven Berkoff'],
#  ['Jake Gyllenhaal',
#   'Gemma Arterton',
#   'Ben Kingsley',
#   'Alfred Molina',
#   'Steve Toussaint'],
#  ['Russell Crowe',
#   'Cate Blanchett',
#   'Mark Strong',
#   'Oscar Isaac',
#   'LÃ©a Seydoux'],
#  ['Jeff Bridges',
#   'Hailee Steinfeld',
#   'Matt Damon',
#   'Josh Brolin',
#   'Barry Pepper'],
#  ['Sam Worthington',
#   'Liam Neeson',
#   'Ralph Fiennes',
#   'Gemma Arterton',
#   'Jason Flemyng'],
#  ['Nicolas Cage',
#   'Jay Baruchel',
#   'Monica Bellucci',
#   'Alfred Molina',
#   'Teresa Palmer'],
#  ['Jesse Eisenberg',
#   'Andrew Garfield',
#   'Justin Timberlake',
#   'Armie Hammer',
#   'Max Minghella'],
#  ['Michael Cera',
#   'Mary Elizabeth Winstead',
#   'Kieran Culkin',
#   'Chris Evans',
#   'Anna Kendrick'],
#  ['Robert De Niro',
#   'Ben Stiller',
#   'Owen Wilson',
#   'Dustin Hoffman',
#   'Barbra Streisand'],
#  ['Topher Grace',
#   'Alice Braga',
#   'Laurence Fishburne',
#   'Adrien Brody',
#   'Danny Trejo'],
#  ['Logan Lerman',
#   'Brandon T. Jackson',
#   'Alexandra Daddario',
#   'Jake Abel',
#   'Sean Bean'],
#  ['Denzel Washington',
#   'Chris Pine',
#   'Rosario Dawson',
#   'Ethan Suplee',
#   'Kevin Corrigan'],
#  ['Mike Myers',
#   'Eddie Murphy',
#   'Cameron Diaz',
#   'Antonio Banderas',
#   'Julie Andrews'],
#  ['Amanda Seyfried',
#   'Channing Tatum',
#   'Henry Thomas',
#   'Richard Jenkins',
#   'Scott Porter'],
#  ['Liam Neeson',
#   'Bradley Cooper',
#   'Jessica Biel',
#   'Sharlto Copley',
#   'Patrick Wilson'],
#  ['Bruce Willis',
#   'John Malkovich',
#   'Helen Mirren',
#   'Mary-Louise Parker',
#   'Karl Urban'],
#  ['Danny Trejo',
#   'Michelle Rodriguez',
#   'Jessica Alba',
#   'Robert De Niro',
#   'Lindsay Lohan'],
#  ['Adam Sandler',
#   'Salma Hayek',
#   'Maria Bello',
#   'Steve Buscemi',
#   'Maya Rudolph'],
#  ['Denzel Washington',
#   'Gary Oldman',
#   'Michael Gambon',
#   'Mila Kunis',
#   'Jennifer Beals'],
#  ['Steve Carell',
#   'Tina Fey',
#   'Mark Wahlberg',
#   'Taraji P. Henson',
#   'Jimmi Simpson'],
#  ['Ben Affleck', 'Rebecca Hall', 'Jeremy Renner', 'Jon Hamm', 'Blake Lively'],
#  ['Kristen Stewart',
#   'Robert Pattinson',
#   'Taylor Lautner',
#   'Ashley Greene',
#   'Peter Facinelli'],
#  ['Will Ferrell', 'Brad Pitt', 'Tina Fey', 'Jonah Hill', 'David Cross'],
#  ['Noah Ringer',
#   'Nicola Peltz',
#   'Jackson Rathbone',
#   'Dev Patel',
#   'Shaun Toub'],
#  ['Will Ferrell',
#   'Mark Wahlberg',
#   'Eva Mendes',
#   'Samuel L. Jackson',
#   'Dwayne Johnson'],
#  ['Rick Malambri',
#   'Adam G. Sevani',
#   'Joe Slaughter',
#   'Sharni Vinson',
#   'Alyson Stoner'],
#  ['Colin Firth',
#   'Geoffrey Rush',
#   'Helena Bonham Carter',
#   'Guy Pearce',
#   'Timothy Spall'],
#  ['Jake Gyllenhaal',
#   'Anne Hathaway',
#   'Oliver Platt',
#   'Hank Azaria',
#   'Gabriel Macht'],
#  ['Colin Farrell',
#   'Dejan Angelov',
#   'DragoÈ™ Bucur',
#   'Ed Harris',
#   'Jim Sturgess'],
#  ['Jude Law',
#   'Forest Whitaker',
#   'Alice Braga',
#   'Liev Schreiber',
#   'Carice van Houten'],
#  ['Tom Cruise',
#   'Cameron Diaz',
#   'Peter Sarsgaard',
#   'Viola Davis',
#   'Jordi MollÃ\xa0'],
#  ['Julia Roberts',
#   'James Franco',
#   'Javier Bardem',
#   'Billy Crudup',
#   'Richard Jenkins'],
#  ['Gerard Butler',
#   'Jennifer Aniston',
#   'Gio Perez',
#   'Siobhan Fallon',
#   'Joel Garland'],
#  ['Amy Adams',
#   'Matthew Goode',
#   'Adam Scott',
#   'John Lithgow',
#   'Flaminia Cinque'],
#  ['Matt Damon', 'Greg Kinnear', 'Brendan Gleeson', 'Amy Ryan', 'Jason Isaacs'],
#  ['Emily Blunt', 'Jason Segel', 'Jack Black', 'Amanda Peet', "Chris O'Dowd"],
#  ['Jennifer Lopez',
#   "Alex O'Loughlin",
#   'Danneel Ackles',
#   'Eric Christian Olsen',
#   'Anthony Anderson'],
#  ['Zac Efron',
#   'Amanda Crew',
#   'Kim Basinger',
#   'Chris Massoglia',
#   'Dave Franco'],
#  ['Jason Bateman',
#   'Jennifer Aniston',
#   'Jeff Goldblum',
#   'Juliette Lewis',
#   'Todd Louiso'],
#  ['Dakota Fanning',
#   'Kristen Stewart',
#   'Michael Shannon',
#   'Riley Keough',
#   'Stella Maeve'],
#  ['Jessica Alba',
#   'Jessica Biel',
#   'Bradley Cooper',
#   'Eric Dane',
#   'Patrick Dempsey'],
#  ['Katie Holmes',
#   'Guy Pearce',
#   'Bailee Madison',
#   'Alan Dale',
#   'Jack Thompson'],
#  ['Tobin Bell',
#   'Costas Mandylor',
#   'Betsy Russell',
#   'Cary Elwes',
#   'Sean Patrick Flanery'],
#  ['Jaden Smith',
#   'Jackie Chan',
#   'Taraji P. Henson',
#   'Yu Rong-Guang',
#   'Tess Liu'],
#  ['Zach Galifianakis',
#   'Robert Downey Jr.',
#   'Michelle Monaghan',
#   'Jamie Foxx',
#   'Juliette Lewis'],
#  ['Bill Nighy',
#   'Emily Blunt',
#   'Rupert Grint',
#   'Rupert Everett',
#   'Eileen Atkins'],
#  ['Ewan McGregor',
#   'Pierce Brosnan',
#   'Jon Bernthal',
#   'Kim Cattrall',
#   'Tom Wilkinson'],
#  ['Russell Crowe', 'Elizabeth Banks', 'Brian Dennehy', 'RZA', 'Moran Atias'],
#  ['Jackie Earle Haley',
#   'Katie Cassidy',
#   'Kyle Gallner',
#   'Kellan Lutz',
#   'Thomas Dekker'],
#  ['Mark Wahlberg',
#   'Christian Bale',
#   'Amy Adams',
#   'Melissa Leo',
#   "Mickey O'Keefe"],
#  ['Jonah Hill', 'Russell Brand', 'Rose Byrne', 'Colm Meaney', 'Sean Combs'],
#  ['Josh Brolin',
#   'John Malkovich',
#   'Megan Fox',
#   'Michael Fassbender',
#   'Will Arnett'],
#  ['Chris Riggi', 'Matt Lanter', 'Jenn Proske', 'Ken Jeong', 'Bradley Dodds'],
#  ['Katherine Heigl',
#   'Ashton Kutcher',
#   'Tom Selleck',
#   "Catherine O'Hara",
#   'Alex Borstein'],
#  ['Paul Bettany', 'Dennis Quaid', 'Kevin Durand', 'Kate Walsh', 'Doug Jones'],
#  ['Sarah Jessica Parker',
#   'Kristin Davis',
#   'Cynthia Nixon',
#   'Kim Cattrall',
#   'Chris Noth'],
#  ['Kristen Bell',
#   'Sigourney Weaver',
#   'Betty White',
#   'Kristin Chenoweth',
#   'Odette Annable'],
#  ['Emma Thompson',
#   'Ralph Fiennes',
#   'Maggie Gyllenhaal',
#   'Maggie Smith',
#   'Rhys Ifans'],
#  ['John Cusack',
#   'Lizzy Caplan',
#   'Rob Corddry',
#   'Craig Robinson',
#   'Clark Duke'],
#  ['Kodi Smit-McPhee',
#   'ChloÃ« Grace Moretz',
#   'Richard Jenkins',
#   'Elias Koteas',
#   'Sasha Barrese'],
#  ['Emily Barclay',
#   'Abbie Cornish',
#   'Essie Davis',
#   'Joel Edgerton',
#   'Deborra-Lee Furness'],
#  ['Chris Brown',
#   'Hayden Christensen',
#   'Matt Dillon',
#   'Michael Ealy',
#   'Idris Elba'],
#  ['Cher', 'Christina Aguilera', 'Eric Dane', 'Cam Gigandet', 'Julianne Hough'],
#  ['Ben Affleck',
#   'Tommy Lee Jones',
#   'Chris Cooper',
#   'Kevin Costner',
#   'Maria Bello'],
#  ['Drew Barrymore',
#   'Justin Long',
#   'Christina Applegate',
#   'Ron Livingston',
#   'Charlie Day'],
#  ['Carey Mulligan',
#   'Andrew Garfield',
#   'Keira Knightley',
#   'Domhnall Gleeson',
#   'Andrea Riseborough'],
#  ['Bruce Willis',
#   'Tracy Morgan',
#   'Juan Carlos HernÃ¡ndez',
#   'Seann William Scott',
#   'Michelle Trachtenberg'],
#  ['Katherine Heigl',
#   'Josh Duhamel',
#   'Christina Hendricks',
#   'Josh Lucas',
#   'Jean Smart'],
#  ['Michael Fassbender',
#   'Olga Kurylenko',
#   'David Morrissey',
#   'Liam Cunningham',
#   'Dominic West'],
#  ['Frances Conroy', 'Robert De Niro', 'Edward Norton', 'Milla Jovovich'],
#  ['Zachary Gordon',
#   'Robert Capron',
#   'ChloÃ« Grace Moretz',
#   'Steve Zahn',
#   'Rachael Harris'],
#  ['Elisabeth Shue',
#   'Adam Scott',
#   "Jerry O'Connell",
#   'Steven R. McQueen',
#   'Jessica Szohr'],
#  ['Rachel McAdams',
#   'Harrison Ford',
#   'Patrick Wilson',
#   'Jeff Goldblum',
#   'Diane Keaton'],
#  ['Hilary Swank',
#   'Minnie Driver',
#   'Bailee Madison',
#   'Loren Dean',
#   'John Pyper-Ferguson'],
#  ['Dwayne Johnson',
#   'Stephen Merchant',
#   'Ashley Judd',
#   'Julie Andrews',
#   'Ryan Sheckler'],
#  ['Naomi Watts', 'Sean Penn', 'Ty Burrell', 'Brooke Smith', 'Bruce McGill'],
#  ['Steve Carell',
#   'Paul Rudd',
#   'Stephanie Szostak',
#   'Jemaine Clement',
#   'Zach Galifianakis'],
#  ['Eric Balfour',
#   'Scottie Thompson',
#   'David Zayas',
#   'Donald Faison',
#   'Brittany Daniel'],
#  ['Helen Mirren',
#   'Sam Worthington',
#   'Jessica Chastain',
#   'Tom Wilkinson',
#   'CiarÃ¡n Hinds'],
#  ['James Marsden',
#   'Nick Nolte',
#   'Christina Applegate',
#   'Bette Midler',
#   'Pascale Hutton'],
#  ['Will Forte',
#   'Kristen Wiig',
#   'Val Kilmer',
#   'Ryan Phillippe',
#   'Maya Rudolph'],
#  ['Reese Witherspoon',
#   'Paul Rudd',
#   'Owen Wilson',
#   'Jack Nicholson',
#   'Kathryn Hahn'],
#  ['Amber Valletta',
#   'Lucas Till',
#   'Jackie Chan',
#   'Billy Ray Cyrus',
#   'George Lopez'],
#  ['Alice Eve',
#   'Jay Baruchel',
#   'Mike Vogel',
#   'Krysten Ritter',
#   'Debra Jo Rupp'],
#  ['Keira Knightley',
#   'Colin Farrell',
#   'Anna Friel',
#   'Ray Winstone',
#   'Jamie Campbell Bower'],
#  ['Matt Damon',
#   'Bryce Dallas Howard',
#   'George McLaren',
#   'Thierry Neuvic',
#   'Cyndi Mayo Davis'],
#  ['Max Thieriot',
#   'John Magaro',
#   'Denzel Whitaker',
#   'Zena Grey',
#   'Nick Lashaway'],
#  ['Evan Rachel Wood',
#   'James McAvoy',
#   'Kevin Kline',
#   'Robin Wright',
#   'Alexis Bledel'],
#  ['Zoe Saldana',
#   'James Marsden',
#   'Martin Lawrence',
#   'Peter Dinklage',
#   'Danny Glover'],
#  ['Owen Wilson',
#   'Emma Stone',
#   'George Lopez',
#   'Christopher Mintz-Plasse',
#   'Steve Coogan'],
#  ['Michael Douglas',
#   'Shia LaBeouf',
#   'Josh Brolin',
#   'Carey Mulligan',
#   'Frank Langella'],
#  ['Rebecca Hall',
#   'Will Ferrell',
#   'Glenn Howerton',
#   'Laura Dern',
#   'Christopher Jordan Wallace'],
#  ['Timothy Olyphant',
#   'Radha Mitchell',
#   'Joe Anderson',
#   'Danielle Panabaker',
#   'Christie Lynn Smith'],
#  ['Hayden Panettiere',
#   'Justin Long',
#   'Dennis Hopper',
#   'Christina Ricci',
#   'Danny Glover'],
#  ['Dan Aykroyd',
#   'Justin Timberlake',
#   'Anna Faris',
#   'Tom Cavanagh',
#   'Christine Taylor'],
#  ['Gwyneth Paltrow',
#   'Garrett Hedlund',
#   'Tim McGraw',
#   'Leighton Meester',
#   'Marshall Chapman'],
#  ['Caitlin Stasey',
#   'Rachel Hurd-Wood',
#   'Phoebe Tonkin',
#   'Deniz Akdeniz',
#   'Lincoln Lewis'],
#  ['Harrison Ford',
#   'Brendan Fraser',
#   'Keri Russell',
#   'Courtney B. Vance',
#   'Meredith Droeger'],
#  ['Chris Messina',
#   'Jacob Vargas',
#   'Bojana NovakoviÄ‡',
#   'Logan Marshall-Green',
#   'Bokeem Woodbine'],
#  ['Paul Giamatti',
#   'Dustin Hoffman',
#   'Rosamund Pike',
#   'Minnie Driver',
#   'Rachelle Lefevre'],
#  ['Mel Gibson',
#   'Ray Winstone',
#   'Danny Huston',
#   'Shawn Roberts',
#   "Denis O'Hare"],
#  ['Brendan Fraser',
#   'Ken Jeong',
#   'Brooke Shields',
#   'Angela Kinsey',
#   'Rob Riggle'],
#  ['Brandon Routh',
#   'Peter Stormare',
#   'Sam Huntington',
#   'Taye Diggs',
#   'Anita Briem'],
#  ['Clifton Collins, Jr.',
#   'Cheech Marin',
#   'MoisÃ©s Arias',
#   'Emilie de Ravin',
#   'Jake T. Austin'],
#  ['Simon Pegg', 'Andy Serkis', 'Isla Fisher', 'Tom Wilkinson', 'Tim Curry'],
#  ['Tyler Perry', 'Janet Jackson', 'Jill Scott', 'Sharon Leal', 'Malik Yoba'],
#  ['Milla Jovovich',
#   'Wentworth Miller',
#   'Ali Larter',
#   'Kim Coates',
#   'Kacey Barnfield'],
#  ['Akshay Kumar',
#   'Aishwarya Rai Bachchan',
#   'Neha Dhupia',
#   'Aditya Roy Kapoor',
#   'Randhir Kapoor'],
#  ['Diane Lane',
#   'John Malkovich',
#   'Scott Glenn',
#   'Dylan Walsh',
#   'Fred Dalton Thompson'],
#  ['Elijah Wood',
#   'Ian McKellen',
#   'Viggo Mortensen',
#   'Liv Tyler',
#   'Orlando Bloom'],
#  ['Daniel Radcliffe',
#   'Rupert Grint',
#   'Emma Watson',
#   'John Cleese',
#   'Robbie Coltrane'],
#  ['Naomi Watts',
#   'Laura Harring',
#   'Ann Miller',
#   'Dan Hedaya',
#   'Justin Theroux'],
#  ['John Goodman',
#   'Billy Crystal',
#   'Mary Gibbs',
#   'Steve Buscemi',
#   'James Coburn'],
#  ['Haley Joel Osment',
#   "Frances O'Connor",
#   'Sam Robards',
#   'Jake Thomas',
#   'Jude Law'],
#  ['Mike Myers',
#   'Eddie Murphy',
#   'Cameron Diaz',
#   'John Lithgow',
#   'Vincent Cassel'],
#  ['RenÃ©e Zellweger',
#   'Colin Firth',
#   'Hugh Grant',
#   'Gemma Jones',
#   'Jim Broadbent'],
#  ['George Clooney',
#   'Brad Pitt',
#   'Matt Damon',
#   'Andy GarcÃ\xada',
#   'Julia Roberts'],
# ...
#   'Zach Galifianakis'],
#  ['Nicolas Cage',
#   'Guy Pearce',
#   'January Jones',
#   'Jennifer Carpenter',
#   'Harold Perrineau'],
#  ['Russell Brand',
#   'Helen Mirren',
#   'Greta Gerwig',
#   'Jennifer Garner',
#   'Geraldine James'],
#  ['Channing Tatum',
#   'Mark Strong',
#   'Jamie Bell',
#   'Donald Sutherland',
#   "Denis O'Hare"],
#  ['Sam Rockwell', 'Jonah Hill', 'Max Records', 'Ari Graynor', 'J.B. Smoove'],
#  ['Leonardo DiCaprio',
#   'Armie Hammer',
#   'Naomi Watts',
#   'Judi Dench',
#   'Geoff Pierson'],
#  ['Ioan Gruffudd',
#   'Richard Roxburgh',
#   'Alice Parkinson',
#   'Daniel Wyllie',
#   'Allison Cratchley'],
#  ['Sarah Jessica Parker',
#   'Pierce Brosnan',
#   'Sarah Shahi',
#   'Busy Philipps',
#   'Olivia Munn'],
#  ['Keira Knightley',
#   'Viggo Mortensen',
#   'Michael Fassbender',
#   'Sarah Gadon',
#   'Vincent Cassel'],
#  ['AnnaSophia Robb',
#   'Helen Hunt',
#   'Lorraine Nicholson',
#   'Carrie Underwood',
#   'Dennis Quaid'],
#  ['Jesse Eisenberg',
#   'Danny McBride',
#   'Aziz Ansari',
#   'Bianca Kajlich',
#   'Nick Swardson'],
#  ['Hayden Panettiere',
#   'Bill Hader',
#   'Joan Cusack',
#   'Patrick Warburton',
#   'Glenn Close'],
#  ['Robert Pattinson',
#   'Reese Witherspoon',
#   'Christoph Waltz',
#   'Tatum Etheridge',
#   'Hal Holbrook'],
#  ['Daniel Craig',
#   'Naomi Watts',
#   'Rachel Weisz',
#   'Marton Csokas',
#   'Elias Koteas'],
#  ['Aimee Teegarden',
#   'Thomas McDonell',
#   'Nicholas Braun',
#   'Faith Ford',
#   'Danielle Campbell'],
#  ['Matthew McConaughey',
#   'Emile Hirsch',
#   'Thomas Haden Church',
#   'Gina Gershon',
#   'Juno Temple'],
#  ['Portia Doubleday',
#   'Martin Lawrence',
#   'Brandon T. Jackson',
#   'Mari Morrow',
#   'Faizon Love'],
#  ['Morgan Freeman',
#   'Ashley Judd',
#   'Harry Connick Jr.',
#   'Nathan Gamble',
#   'Kris Kristofferson'],
#  ['Andy Lau', 'Nicholas Tse', 'Fan Bingbing', 'Jackie Chan', 'Wu Jing'],
#  ['Vin Diesel',
#   'Paul Walker',
#   'Dwayne Johnson',
#   'Jordana Brewster',
#   'Tyrese Gibson'],
#  ['Paula Patton', 'Julie Bowen', 'Meagan Good', 'Mike Epps', 'Angela Bassett'],
#  ['Selena Gomez',
#   'Katie Cassidy',
#   'Cory Monteith',
#   'Leighton Meester',
#   'Andie MacDowell'],
#  ['Meryl Streep',
#   'Anthony Stewart Head',
#   'Harry Lloyd',
#   'Jim Broadbent',
#   'Susan Brown'],
#  ['Dominic Cooper',
#   'Ludivine Sagnier',
#   'Raad Rawi',
#   'Mehmet Ferda',
#   'Philip Quast'],
#  ['Sara Paxton',
#   'Chris Carmack',
#   'Joel David Moore',
#   'Chris Zylka',
#   'Dustin Milligan'],
#  ['Taylor Schilling',
#   'Paul Johansson',
#   "Michael O'Keefe",
#   'Grant Bowler',
#   'Edi Gathegi'],
#  ['Sean Penn',
#   'Frances McDormand',
#   'Judd Hirsch',
#   'Eve Hewson',
#   'Kerry Condon'],
#  ['Glenn Close',
#   'Mia Wasikowska',
#   'Aaron Taylor-Johnson',
#   'Pauline Collins',
#   'Brendan Gleeson'],
#  ['Justin Bieber',
#   'Miley Cyrus',
#   'Usher Raymond',
#   'Jaden Smith',
#   'Sean Kingston'],
#  ['Jason Segel', 'Ed Helms', 'Susan Sarandon', 'Judy Greer', 'Rae Dawn Chong'],
#  ['James McAvoy',
#   'Michael Fassbender',
#   'Jennifer Lawrence',
#   'Kevin Bacon',
#   'Rose Byrne'],
#  ['Elijah Wood',
#   'Ian McKellen',
#   'Viggo Mortensen',
#   'Liv Tyler',
#   'Orlando Bloom'],
#  ['Daniel Radcliffe',
#   'Rupert Grint',
#   'Emma Watson',
#   'Kenneth Branagh',
#   'Richard Harris'],
#  ['Ray Romano',
#   'John Leguizamo',
#   'Denis Leary',
#   'Goran Visnjic',
#   'Jack Black'],
#  ['Matt Damon', 'Franka Potente', 'Chris Cooper', 'Clive Owen', 'Brian Cox'],
#  ['Milla Jovovich',
#   'Michelle Rodriguez',
#   'Eric Mabius',
#   'Ryan McCluskey',
#   'Oscar Pearce'],
#  ['Tobey Maguire',
#   'Willem Dafoe',
#   'Kirsten Dunst',
#   'James Franco',
#   'Cliff Robertson'],
#  ['Ewan McGregor',
#   'Natalie Portman',
#   'Hayden Christensen',
#   'Ian McDiarmid',
#   'Samuel L. Jackson'],
#  ['Leonardo DiCaprio',
#   'Tom Hanks',
#   'Christopher Walken',
#   'Martin Sheen',
#   'Amy Adams'],
#  ['Tommy Lee Jones',
#   'Will Smith',
#   'Rip Torn',
#   'Lara Flynn Boyle',
#   'Johnny Knoxville'],
#  ['Adrien Brody',
#   'Thomas Kretschmann',
#   'Frank Finlay',
#   'Maureen Lipman',
#   'Emilia Fox'],
#  ['Tom Cruise',
#   'Colin Farrell',
#   'Samantha Morton',
#   'Max von Sydow',
#   'Lois Smith'],
#  ['Chris Sanders',
#   'Daveigh Chase',
#   'Tia Carrere',
#   'David Ogden Stiers',
#   'Kevin McDonald'],
#  ['Jason Statham',
#   'Shu Qi',
#   'FranÃ§ois BerlÃ©and',
#   'Matt Schulze',
#   'Ric Young'],
#  ['Vin Diesel',
#   'Asia Argento',
#   'Marton Csokas',
#   'Samuel L. Jackson',
#   'Michael Roof'],
#  ['Joseph Gordon-Levitt',
#   'David Hyde Pierce',
#   'Emma Thompson',
#   'Roscoe Lee Browne',
#   'Martin Short'],
#  ['Pierce Brosnan',
#   'Halle Berry',
#   'Rosamund Pike',
#   'Rick Yune',
#   'Toby Stephens'],
#  ['Cillian Murphy',
#   'Naomie Harris',
#   'Noah Huntley',
#   'Christopher Dunne',
#   'Emma Hitching'],
#  ['Jennifer Lopez',
#   'Ralph Fiennes',
#   'Natasha Richardson',
#   'Stanley Tucci',
#   'Tyler Posey'],
#  ['Wesley Snipes',
#   'Kris Kristofferson',
#   'Ron Perlman',
#   'Leonor Varela',
#   'Norman Reedus'],
#  ['Leonardo DiCaprio',
#   'Daniel Day-Lewis',
#   'Cameron Diaz',
#   'Liam Neeson',
#   'Brendan Gleeson'],
#  ['Jodie Foster',
#   'Kristen Stewart',
#   'Forest Whitaker',
#   'Dwight Yoakam',
#   'Jared Leto'],
#  ['Michael J. Fox',
#   'Geena Davis',
#   'Hugh Laurie',
#   'Jonathan Lipnicki',
#   'Anna Hoelck'],
#  ['Ryan Reynolds', 'Tara Reid', 'Tim Matheson', 'Kal Penn', 'Simon Helberg'],
#  ['Eminem',
#   'Mekhi Phifer',
#   'Brittany Murphy',
#   'Kim Basinger',
#   'Michael Shannon'],
#  ['Adam Sandler',
#   'Winona Ryder',
#   'John Turturro',
#   'Allen Covert',
#   'Peter Gallagher'],
#  ['Sandra Bullock', 'Hugh Grant', 'Alicia Witt', 'Dana Ivey', 'Robert Klein'],
#  ['Mel Gibson',
#   'Joaquin Phoenix',
#   'Rory Culkin',
#   'Abigail Breslin',
#   'Cherry Jones'],
#  ['Naomi Watts',
#   'Martin Henderson',
#   'David Dorfman',
#   'Brian Cox',
#   'Shannon Cochran'],
#  ['Mandy Moore',
#   'Shane West',
#   'Peter Coyote',
#   'Daryl Hannah',
#   'Lauren German'],
#  ['Nia Vardalos',
#   'John Corbett',
#   'Lainie Kazan',
#   'Michael Constantine',
#   'Andrea Martin'],
#  ['Hugh Grant',
#   'Nicholas Hoult',
#   'Toni Collette',
#   'Rachel Weisz',
#   'Sharon Small'],
#  ['Arnold Schwarzenegger',
#   'Francesca Neri',
#   'Elias Koteas',
#   'Cliff Curtis',
#   'John Turturro'],
#  ['Colin Farrell',
#   'Kiefer Sutherland',
#   'Forest Whitaker',
#   'Radha Mitchell',
#   'Katie Holmes'],
#  ['Patrick Stewart',
#   'Jonathan Frakes',
#   'LeVar Burton',
#   'Brent Spiner',
#   'Gates McFadden'],
#  ['Christian Bale',
#   'Taye Diggs',
#   'Emily Watson',
#   'Angus Macfadyen',
#   'Sean Bean'],
#  ['Jennifer Aniston',
#   'Jake Gyllenhaal',
#   'Zooey Deschanel',
#   'John C. Reilly',
#   'Deborah Rush'],
#  ['Nicole Kidman',
#   'Julianne Moore',
#   'Meryl Streep',
#   'Stephen Dillane',
#   'Miranda Richardson'],
#  ['Tom Hanks',
#   'Tyler Hoechlin',
#   'Jennifer Jason Leigh',
#   'Liam Aiken',
#   'Paul Newman'],
#  ['Mike Myers',
#   'BeyoncÃ© Knowles',
#   'Seth Green',
#   'Michael York',
#   'Mindy Sterling'],
#  ['Tim Allen',
#   'Elizabeth Mitchell',
#   'David Krumholtz',
#   'Eric Lloyd',
#   'Spencer Breslin'],
#  ['Al Pacino',
#   'Robin Williams',
#   'Maura Tierney',
#   'Hilary Swank',
#   'Martin Donovan'],
#  ['Gabriel Byrne',
#   'Julianna Margulies',
#   'Desmond Harrington',
#   'Ron Eldard',
#   'Isaiah Washington'],
#  ['Freddie Prinze Jr.',
#   'Sarah Michelle Gellar',
#   'Matthew Lillard',
#   'Linda Cardellini',
#   'Rowan Atkinson'],
#  ['Matt Damon',
#   'James Cromwell',
#   'Daniel Studi',
#   'Chopper Bernet',
#   'Jeff LeBeau'],
#  ['Sylvester Stallone',
#   'Courtney B. Vance',
#   'Tom Berenger',
#   'Charles S. Dutton',
#   'Jeffrey Wright'],
#  ['Dwayne Johnson',
#   'Kelly Hu',
#   'Michael Clarke Duncan',
#   'Steven Brand',
#   'Bernard Hill'],
#  ['Eddie Murphy',
#   'Owen Wilson',
#   'Famke Janssen',
#   'Keith Dallas',
#   'Malcolm McDowell'],
#  ['Mel Gibson',
#   'Greg Kinnear',
#   'Madeleine Stowe',
#   'Sam Elliott',
#   'Chris Klein'],
#  ['Johnny Knoxville',
#   'Bam Margera',
#   'Steve-O',
#   'Chris Pontius',
#   'Dave England'],
#  ['Salma Hayek',
#   'Alfred Molina',
#   'MÃ\xada Maestro',
#   'Patricia Reyes SpÃ\xadndola',
#   'Diego Luna'],
#  ['Sandra Bullock',
#   'Ben Chaplin',
#   'Ryan Gosling',
#   'Michael Pitt',
#   'Agnes Bruckner'],
#  ['Nicolas Cage',
#   'Meryl Streep',
#   'Chris Cooper',
#   'Tilda Swinton',
#   'Cara Seymour'],
#  ['Reese Witherspoon',
#   'Josh Lucas',
#   'Patrick Dempsey',
#   'Candice Bergen',
#   'Rhona Mitra'],
#  ['Ice Cube',
#   'Anthony Anderson',
#   'Cedric the Entertainer',
#   'Sean Patrick Thomas',
#   'Eve'],
#  ['Kurt Russell',
#   'Scott Speedman',
#   'Michael Michele',
#   'Brendan Gleeson',
#   'Ving Rhames'],
#  ['Guy Pearce', 'Samantha Mumba', 'Phyllida Law', 'Laura Kirk', 'Mark Addy'],
#  ['Wesley Snipes', 'Ving Rhames', 'Peter Falk', 'Michael Rooker', 'Jon Seda'],
#  ['Cameron Diaz',
#   'Christina Applegate',
#   'Thomas Jane',
#   'Selma Blair',
#   'Jason Bateman'],
#  ['Nicolas Cage',
#   'Adam Beach',
#   'Peter Stormare',
#   'Noah Emmerich',
#   'Mark Ruffalo'],
#  ['Denzel Washington',
#   'Robert Duvall',
#   'Anne Heche',
#   'Kimberly Elise',
#   'Daniel E. Smith'],
#  ['Richard Gere',
#   'Diane Lane',
#   'Olivier Martinez',
#   'Erik Per Sullivan',
#   'Zeljko Ivanek'],
#  ['Ben Affleck',
#   'Samuel L. Jackson',
#   'Kim Staunton',
#   'Toni Collette',
#   'Sydney Pollack'],
#  ['Harrison Ford',
#   'Liam Neeson',
#   'Peter Sarsgaard',
#   'Joss Ackland',
#   'John Shrapnel'],
#  ['Stuart Townsend',
#   'Aaliyah',
#   'Marguerite Moreau',
#   'Vincent PÃ©rez',
#   'Paul McGann'],
#  ['Antonio Banderas',
#   'Carla Gugino',
#   'Alexa PenaVega',
#   'Daryl Sabara',
#   'Steve Buscemi'],
#  ['Jennifer Lopez',
#   'Billy Campbell',
#   'Tessa Allen',
#   'Juliette Lewis',
#   'Dan Futterman'],
#  ['Ice Cube',
#   'Mike Epps',
#   'John Witherspoon',
#   'Don Curry',
#   'Anna Maria Horsford'],
#  ['Harriet Owen',
#   'Blayne Weaver',
#   'Jeff Bennett',
#   'Kath Soucie',
#   'Corey Burton'],
#  ['Jason Segel',
#   'Devon Sawa',
#   'Jason Schwartzman',
#   'Jaime King',
#   'Laura Prepon'],
#  ['Catherine Zeta-Jones',
#   'RenÃ©e Zellweger',
#   'Queen Latifah',
#   'Richard Gere',
#   'Christine Baranski'],
#  ['Robin Williams',
#   'Connie Nielsen',
#   'Michael Vartan',
#   'Erin Daniels',
#   'Eriq La Salle'],
#  ['Rebecca Romijn',
#   'Antonio Banderas',
#   'Peter Coyote',
#   'Rie Rasmussen',
#   'Gregg Henry'],
#  ['Robert De Niro',
#   'James Franco',
#   'Frances McDormand',
#   'Eliza Dushku',
#   'George Dzundza'],
#  ['Christian Bale',
#   'Matthew McConaughey',
#   'Izabella Scorupco',
#   'Gerard Butler',
#   'Alexander Siddig'],
#  ['Robert De Niro',
#   'Rachael Harris',
#   'Eddie Murphy',
#   'Zaid Farid',
#   'William Shatner'],
#  ['Ashley Judd',
#   'Morgan Freeman',
#   'Jim Caviezel',
#   'Amanda Peet',
#   'Adam Scott'],
#  ['Bruce Willis',
#   'Colin Farrell',
#   'Terrence Howard',
#   'Marcel IureÈ™',
#   'Cole Hauser'],
#  ['Jack Nicholson',
#   'Kathy Bates',
#   'Hope Davis',
#   'Dermot Mulroney',
#   'June Squibb'],
#  ['Kate Bosworth',
#   'Matthew Davis',
#   'Michelle Rodriguez',
#   'Sanoe Lake',
#   'Mika Boorem'],
#  ['Clint Eastwood',
#   'Jeff Daniels',
#   'Anjelica Huston',
#   'Wanda De Jesus',
#   'Tina Lifford'],
#  ['George Clooney',
#   'Natascha McElhone',
#   'Viola Davis',
#   'Jeremy Davies',
#   'Ulrich Tukur'],
#  ['Heath Ledger',
#   'Wes Bentley',
#   'Kate Hudson',
#   'Djimon Hounsou',
#   'Michael Sheen'],
#  ['Richard Gere',
#   'Laura Linney',
#   'Will Patton',
#   'Bob Tracey',
#   'Debra Messing'],
#  ['Julianne Moore',
#   'Dennis Quaid',
#   'Dennis Haysbert',
#   'Patricia Clarkson',
#   'Viola Davis'],
#  ['Dennis Quaid',
#   'Rachel Griffiths',
#   'Beth Grant',
#   'Angus T. Jones',
#   'Brian Cox'],
#  ['Anthony Hopkins',
#   'Chris Rock',
#   'Peter Stormare',
#   'Gabriel Macht',
#   'Kerry Washington'],
#  ['Sam Rockwell',
#   'Drew Barrymore',
#   'Julia Roberts',
#   'Rutger Hauer',
#   'Brad Pitt'],
#  ['Charlize Theron',
#   'Kevin Bacon',
#   'Courtney Love',
#   'Stuart Townsend',
#   'Dakota Fanning'],
#  ['Jesse Bradford',
#   'Paula GarcÃ©s',
#   'Robin Thomas',
#   'French Stewart',
#   'Michael Biehn'],
#  ['Jamie Lee Curtis',
#   'Brad Loree',
#   'Busta Rhymes',
#   'Bianca Kajlich',
#   'Katee Sackhoff'],
#  ['Frankie Muniz',
#   'Paul Giamatti',
#   'Amanda Bynes',
#   'Amanda Detmer',
#   'Donald Faison'],
#  ['Derek Luke',
#   'Malcolm David Kelley',
#   'Cory Hodges',
#   'Denzel Washington',
#   'Joy Bryant'],
#  ['Kieran Culkin',
#   'Claire Danes',
#   'Jeff Goldblum',
#   'Jared Harris',
#   'Amanda Peet'],
#  ['Cuba Gooding Jr.',
#   'Horatio Sanz',
#   'Roselyn SÃ¡nchez',
#   'Vivica A. Fox',
#   'Maurice Godin'],
#  ['Britney Spears',
#   'Zoe Saldana',
#   'Taryn Manning',
#   'Anson Mount',
#   'Dan Aykroyd'],
#  ['Eddie Murphy',
#   'Randy Quaid',
#   'Rosario Dawson',
#   'Joe Pantoliano',
#   'Jay Mohr'],
#  ['Katie Holmes',
#   'Benjamin Bratt',
#   'Charlie Hunnam',
#   'Zooey Deschanel',
#   'Fred Ward'],
#  ['Anthony Hopkins',
#   'Edward Norton',
#   'Ralph Fiennes',
#   'Harvey Keitel',
#   'Emily Watson'],
#  ['Matthew Perry',
#   'Elizabeth Hurley',
#   'Vincent Pastore',
#   'Bruce Campbell',
#   'Cedric the Entertainer'],
#  ['Kevin Costner',
#   'Joe Morton',
#   'Ron Rifkin',
#   'Susanna Thompson',
#   'Kathy Bates'],
#  ['Nick Cannon', 'Zoe Saldana', 'Orlando Jones', 'Leonard Roberts', 'GQ'],
#  ['Ice Cube', 'Mike Epps', 'Tommy Flanagan', 'Carmen Chaplin', 'Eva Mendes'],
#  ['Stephen Dorff',
#   'Natascha McElhone',
#   'Stephen Rea',
#   'Udo Kier',
#   'Amelia Curtis'],
#  ['Greg Kinnear', 'Willem Dafoe', 'Rita Wilson', 'Maria Bello', 'Ron Leibman'],
#  ['Gwyneth Paltrow',
#   'Aaron Eckhart',
#   'Jeremy Northam',
#   'Jennifer Ehle',
#   'Lena Headey'],
#  ['Tim Allen',
#   'Rene Russo',
#   'Patrick Warburton',
#   'Ben Foster',
#   'Zooey Deschanel'],
#  ['Eddie Griffin',
#   'Chris Kattan',
#   'Denise Richards',
#   'Aunjanue Ellis',
#   'Chi McBride'],
#  ['Robert Downey Jr.',
#   'Chris Evans',
#   'Mark Ruffalo',
#   'Chris Hemsworth',
#   'Scarlett Johansson'],
#  ['Kate Beckinsale',
#   'Stephen Rea',
#   'Michael Ealy',
#   'Theo James',
#   'India Eisley'],
#  ['Christian Bale',
#   'Michael Caine',
#   'Gary Oldman',
#   'Anne Hathaway',
#   'Tom Hardy'],
#  ['Jamie Foxx',
#   'Christoph Waltz',
#   'Leonardo DiCaprio',
#   'Kerry Washington',
#   'Samuel L. Jackson'],
#  ['Daniel Craig',
#   'Judi Dench',
#   'Javier Bardem',
#   'Ralph Fiennes',
#   'Naomie Harris'],
#  ['Jeremy Renner',
#   'Rachel Weisz',
#   'Edward Norton',
#   'Scott Glenn',
#   'Stacy Keach'],
#  ['Ian McKellen',
#   'Martin Freeman',
#   'Richard Armitage',
#   'Andy Serkis',
#   'Cate Blanchett'],
#  ['Noomi Rapace',
#   'Michael Fassbender',
#   'Charlize Theron',
#   'Idris Elba',
#   'Guy Pearce'],
#  ['Bradley Cooper',
#   'Jennifer Lawrence',
#   'Robert De Niro',
#   'Jacki Weaver',
#   'Chris Tucker'],
#  ['Andrew Garfield',
#   'Emma Stone',
#   'Rhys Ifans',
#   'Denis Leary',
#   'Martin Sheen'],
#  ['Kelly Macdonald',
#   'Julie Walters',
#   'Billy Connolly',
#   'Emma Thompson',
#   'Kevin McKidd'],
#  ['Kristen Stewart',
#   'Charlize Theron',
#   'Chris Hemsworth',
#   'Sam Claflin',
#   'Ian McShane'],
#  ['Channing Tatum',
#   'Jonah Hill',
#   'Brie Larson',
#   'Dave Franco',
#   'Ellie Kemper'],
#  ['Suraj Sharma',
#   'Irrfan Khan',
#   'Ayush Tandon',
#   'Gautam Belur',
#   'Adil Hussain'],
#  ['John Leguizamo',
#   'Ray Romano',
#   'Chris Wedge',
#   'Denis Leary',
#   'Seann William Scott'],
#  ['Mark Wahlberg',
#   'Mila Kunis',
#   'Seth MacFarlane',
#   'Joel McHale',
#   'Giovanni Ribisi'],
#  ['Tom Cruise',
#   'Rosamund Pike',
#   'Richard Jenkins',
#   'David Oyelowo',
#   'Werner Herzog'],
#  ['Naomi Watts',
#   'Ewan McGregor',
#   'Tom Holland',
#   'Samuel Joslin',
#   'Oaklee Pendergast'],
#  ['John C. Reilly',
#   'Sarah Silverman',
#   'Jane Lynch',
#   'Jack McBrayer',
#   'Jamie Elman'],
#  ['Anna Kendrick',
#   'Skylar Astin',
#   'Brittany Snow',
#   'Anna Camp',
#   'Rebel Wilson'],
#  ['Will Smith',
#   'Tommy Lee Jones',
#   'Josh Brolin',
#   'Michael Stuhlbarg',
#   'Emma Thompson'],
#  ['Jennifer Lawrence',
#   'Josh Hutcherson',
#   'Liam Hemsworth',
#   'Woody Harrelson',
#   'Elizabeth Banks'],
#  ['Colin Farrell',
#   'Kate Beckinsale',
#   'Jessica Biel',
#   'Bryan Cranston',
#   'Bill Nighy'],
#  ['Tom Hanks', 'Halle Berry', 'Jim Broadbent', 'Hugo Weaving', 'Jim Sturgess'],
#  ['Sylvester Stallone',
#   'Jason Statham',
#   'Dolph Lundgren',
#   'Bruce Willis',
#   'Arnold Schwarzenegger'],
#  ['Liam Neeson',
#   'Maggie Grace',
#   'Famke Janssen',
#   'Rade Serbedzija',
#   'Luke Grimes'],
#  ['Johnny Depp',
#   'Michelle Pfeiffer',
#   'Helena Bonham Carter',
#   'Jackie Earle Haley',
#   'Jonny Lee Miller'],
#  ['Logan Lerman', 'Emma Watson', 'Ezra Miller', 'Paul Rudd', 'Nina Dobrev'],
#  ['Ben Affleck',
#   'Bryan Cranston',
#   'Alan Arkin',
#   'John Goodman',
#   'Victor Garber'],
#  ['Jason Biggs',
#   'Alyson Hannigan',
#   'Seann William Scott',
#   'Chris Klein',
#   'Thomas Ian Nicholas'],
#  ...]

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '...', '2': '...'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
